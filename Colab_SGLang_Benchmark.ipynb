# %% [markdown]
# # LLM Inference Benchmark (SGLang)
#
# This notebook benchmarks SGLang inference across three configurations, each run
# in its own cell with a **fresh SGLang server instance**:
#
# | Test | Configuration | Description |
# |------|--------------|-------------|
# | 1 | **Baseline** | Standard SGLang with RadixAttention (automatic prefix caching) |
# | 2 | **No RadixAttention** | RadixAttention disabled to measure its benefit |
# | 3 | **Torch Compile** | torch.compile optimization for compute-bound speedups |
#
# ## Metrics collected per test
# - **Throughput**: Output tokens/s, total tokens/s, requests/s
# - **Latency**: TTFT p50/p95/p99, ITL p50/p95/p99, request latency
# - **Goodput**: Successful tokens/s, success rate, SLA compliance
# - **KV Cache**: Utilization %, prefix cache hit rate
#
# ## Workloads
# - `random_short` — Short prompts (<100 tokens), tests raw decode speed
# - `random_medium` — Medium prompts (100-500 tokens), balanced workload
# - `long_context` — Long prompts (500-1500 tokens), stresses prefill throughput
# - `mixed_context` — 50% very-long (≥800 tokens) + 50% very-short (<50 tokens); shows chunked-prefill head-of-line blocking
# - `shared_prefix` — Same prefix + different questions, tests KV cache reuse
# - `repetitive` — Repetitive patterns, tests n-gram speculation
# - `code` — Code generation, tests structured output speculation
#
# Each test saves its own DataFrame and CSV. After all tests, comprehensive
# comparison graphs are generated.
#
# ## SGLang Key Features Tested
# - **RadixAttention**: Automatic KV cache reuse across requests sharing prefixes
# - **torch.compile**: JIT compilation for reduced kernel launch overhead
# - **FlashInfer backend**: High-performance attention kernels for A100

# %% [markdown]
# ---
# ## 1. Install Dependencies

# %%
# Install SGLang with all dependencies (includes FlashInfer for A100)
# !pip install "sglang[all]>=0.4.0" -q
# !pip install "openai>=1.51.0" "transformers>=4.44.2" \
    "tokenizers>=0.19.1" "accelerate" "GPUtil" "httpx>=0.27" "pandas" \
    "psutil" "torch" "gpustat" "nvidia-ml-py" "seaborn" "matplotlib" \
    "huggingface_hub" "datasets" "aiohttp" "nest_asyncio" -q

# Verify SGLang install
import sglang
print(f"SGLang version: {sglang.__version__}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 129.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 MB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 124.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 113.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 105.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.7/488.7 kB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 91.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 126.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 59.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.2/343.2 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.9/635.9 kB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 67.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.1/232.1 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 124.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 104.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 61.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.9/356.9 kB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 118.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.4/315.4 kB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 78.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 49.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 59.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 113.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 109.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 153.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 110.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 134.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.3/608.3 kB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 740.8/740.8 kB 54.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.4/935.4 kB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.1/209.1 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 32.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.0 which is incompatible.
# google-adk 1.29.0 requires PyYAML<7.0.0,>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.6 which is incompatible.
# rmm-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.0 which is incompatible.
# cuvs-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
# pylibcudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
# pylibraft-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 12.9.0 which is incompatible.
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 9.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 14.9 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done
#   Building wheel for gpustat (pyproject.toml) ... done
# SGLang version: 0.5.10.post1

# %% [markdown]
# ## 2. Hugging Face Authentication

# %%
import os

os.environ["HF_TOKEN"] = 'YOUR_HF_TOKEN_HERE'

from huggingface_hub import login
login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## 3. Download Models
#
# Downloads the target model. The draft model is also downloaded for parity
# with the vLLM benchmark setup (not used by SGLang tests).

# %%
from huggingface_hub import snapshot_download

target_model = "meta-llama/Llama-3.2-3B-Instruct"

print(f"Downloading {target_model}...")
snapshot_download(target_model)
print("Model downloaded.")
# Out:
# Downloading meta-llama/Llama-3.2-3B-Instruct...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Model downloaded.

# %% [markdown]
# ## 4. Upload Benchmark Module
#
# Upload the `llm_benchmark/` folder to your Colab environment.

# %%
import os

required_files = [
    "llm_benchmark/__init__.py",
    "llm_benchmark/benchmark_core.py",
    "llm_benchmark/server.py",
    "llm_benchmark/workloads.py",
    "llm_benchmark/metrics.py",
    "llm_benchmark/stats.py",
    "llm_benchmark/runner.py",
]

missing = [f for f in required_files if not os.path.exists(f)]
if missing:
    print("Missing files:")
    for f in missing:
        print(f"  - {f}")
    print("\nPlease upload the llm_benchmark folder.")
else:
    print("llm_benchmark module found. All files present.")
# Out:
# llm_benchmark module found. All files present.

# %% [markdown]
# ## 4b. Dataset File Configuration
#
# Both vLLM and SGLang notebooks share the same prompts via a JSON dataset file.
# - If the file exists, prompts are loaded from it (ensuring identical inputs across engines).
# - If it does not exist, prompts are generated from the Dolly dataset and saved to the file.
#
# Set `DATASET_FILE` below to control the path. Upload the file to Colab, or
# leave the default to auto-generate on first run.

# %%
import os

# Path to the shared dataset file.
# Both vLLM and SGLang notebooks should point to the SAME file.
DATASET_FILE = "benchmark_prompts.json"

# Set to False to disable KV cache metric polling during benchmarks.
# When disabled, KV cache columns will report 0 / NaN instead of
# polling the server's /metrics endpoint every second.
COLLECT_KV_STATS = False

if os.path.exists(DATASET_FILE):
    print(f"Dataset file found: {DATASET_FILE}")
    print(f"  Size: {os.path.getsize(DATASET_FILE) / 1024:.1f} KB")
    print("  Prompts will be loaded from this file.")
else:
    print(f"Dataset file not found: {DATASET_FILE}")
    print("  Prompts will be generated and saved to this file.")
    print("  Tip: Upload a previously generated file to use identical prompts across runs.")
# Out:
# Dataset file found: benchmark_prompts.json
#   Size: 2236.7 KB
#   Prompts will be loaded from this file.

# %% [markdown]
# ## 5. Initialize Benchmark Environment
#
# This cell:
# 1. Detects GPU and selects optimal dtype
# 2. Loads the tokenizer (shared across all tests)
# 3. Loads workloads from a shared dataset file (or generates & saves one)
# 4. Defines the `run_single_config()` helper used by each test cell

# %%
import time
import pandas as pd
import numpy as np
from transformers import AutoTokenizer

from llm_benchmark import (
    detect_gpu,
    pick_dtype,
    ServerConfig,
    ServerProcess,
    WorkloadGenerator,
    WORKLOAD_CONFIGS,
    run_workload,
    TestConfig,
    SGLANG_TEST_CONFIGS,
    DEFAULT_BATCH_SIZES,
    StatisticsReporter,
)

# ---- Shared state (computed once, used by every test cell) ----
MODEL_ID = "meta-llama/Llama-3.2-3B-Instruct"
BATCH_SIZES = DEFAULT_BATCH_SIZES          # [1, 8, 32, 64]
WORKLOAD_NAMES = list(WORKLOAD_CONFIGS.keys())

# Per-workload batch-size caps (prevents OOM / server stalls).
# SGLang uses a fixed-size static KV cache pool (--mem-fraction-static).
# Unlike vLLM's dynamic allocation, SGLang crashes instead of rejecting
# requests when the pool is exhausted.
MAX_BATCH = {
    "shared_prefix": 32,
    "repetitive": 8,
    "long_context": 32,
    "mixed_context": 32,   # half long (>=1500 tok) prompts stress static KV pool
}

gpu_info = detect_gpu()
dtype = pick_dtype(gpu_info)
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)

workload_gen = WorkloadGenerator(MODEL_ID)

# --- Load or generate workloads ---
if os.path.exists(DATASET_FILE):
    workload_gen.load_workloads(DATASET_FILE)
    print(f"\n✅ Loaded prompts from {DATASET_FILE}")
else:
    workload_gen.prepare_workloads(
        n_random=max(BATCH_SIZES),
        n_shared=max(BATCH_SIZES),
    )
    workload_gen.save_workloads(DATASET_FILE)
    print(f"\n💾 Generated and saved prompts to {DATASET_FILE}")

print(f"\nGPU: {gpu_info['name']} ({gpu_info['memory_gb']:.1f} GB, CC {gpu_info['cc']})")
print(f"Dtype: {dtype}")
print(f"Batch sizes: {BATCH_SIZES}")
print(f"Workloads: {list(workload_gen._workloads.keys())}")


def run_single_config(
    config: TestConfig,
    batch_sizes=None,
    workload_names=None,
    warmup: int = 3,
) -> pd.DataFrame:
    """
    For *config*, start a FRESH SGLang server for EACH workload, run every
    batch size against it, then shut it down before moving to the next
    workload.  This isolates workloads so a crash, OOM, or KV pool
    fragmentation in one cannot affect the next.

    All rows still go into a single reporter and one CSV — same output
    shape as before.  Cost: one extra server start per workload (~30-60 s
    each on an L4), so 9 workloads ≈ 9 startups per config.
    """
    batch_sizes = batch_sizes or BATCH_SIZES
    workload_names = workload_names or WORKLOAD_NAMES
    reporter = StatisticsReporter()

    # -- build server launch args (same for every workload) --
    extra_args = list(config.extra_args)
    # Note: spec_config is vLLM-specific; SGLang configs use extra_args instead
    if config.spec_config:
        extra_args.extend(["--speculative-config", config.spec_config])

    for wl_name in workload_names:
        wl_cfg = WORKLOAD_CONFIGS[wl_name]
        prompts = workload_gen.get_workload(wl_name)
        if not prompts:
            print(f"\n=== {wl_name} — SKIPPED (no prompts loaded) ===")
            continue
        cap = MAX_BATCH.get(wl_name, float("inf"))

        print(f"\n{'=' * 60}")
        print(f"Workload: {wl_name} — {wl_cfg.description}")
        print(f"{'=' * 60}")

        # Fresh server for this workload
        server_cfg = ServerConfig(
            engine=config.engine,
            model_id=MODEL_ID,
            port=8000,
            dtype=dtype,
            gpu_mem_util=config.gpu_mem_util,
            max_model_len=8192,
            extra_args=extra_args,
        )
        server = ServerProcess(server_cfg)
        try:
            server.start()
        except Exception as e:
            print(f"  Server failed to start for {wl_name}: {e}")
            continue

        try:
            # Warmup the fresh server
            if warmup > 0:
                print("  Warming up...")
                wp = workload_gen.get_workload("random_short")[:warmup]
                _ = run_workload(
                    base_url=server_cfg.base_url(),
                    model=MODEL_ID,
                    prompts=wp,
                    tokenizer=tokenizer,
                    concurrency=warmup,
                    max_tokens=32,
                    collect_kv_stats=COLLECT_KV_STATS,
                )

            # Run every batch size on this server
            for bs in batch_sizes:
                if bs > cap:
                    print(f"    Batch {bs:>4d} ... skipped (cap {int(cap)} for {wl_name})")
                    continue

                print(f"    Batch {bs:>4d} ... ", end="", flush=True)
                try:
                    bm = run_workload(
                        base_url=server_cfg.base_url(),
                        model=MODEL_ID,
                        prompts=prompts[:bs],
                        tokenizer=tokenizer,
                        concurrency=bs,
                        max_tokens=wl_cfg.max_tokens,
                        temperature=wl_cfg.temperature,
                        collect_kv_stats=COLLECT_KV_STATS,
                    )
                    reporter.add_run(
                        config_name=config.name,
                        workload_name=wl_name,
                        batch_size=bs,
                        batch_metrics=bm,
                    )
                    tp = bm.throughput_output_tok_s
                    print(f"{tp:,.1f} tok/s  ({bm.successful_requests}/{bm.total_requests} ok)")
                except Exception as e:
                    print(f"ERROR: {e}")
        finally:
            server.stop()

    df = reporter.to_dataframe()
    csv_name = f"results_{config.name}.csv"
    df.to_csv(csv_name, index=False)
    print(f"\n  Saved {len(df)} rows → {csv_name}")
    return df
# Out:
# 📊 Workload Statistics:
# ------------------------------------------------------------
#   random_short:
#     Prompts: 64
#     Tokens - min: 1, max: 4, mean: 3.7, median: 4.0
#   random_medium:
#     Prompts: 64
#     Tokens - min: 100, max: 103, mean: 101.2, median: 101.0
#   long_context:
#     Prompts: 64
#     Tokens - min: 500, max: 534, mean: 517.4, median: 517.0
#   mixed_context:
#     Prompts: 64
#     Tokens - min: 1, max: 6228, mean: 3056.2, median: 3008.0
#   shared_prefix:
#     Prompts: 64
#     Tokens - min: 318, max: 325, mean: 320.6, median: 320.0
#   repetitive:
#     Prompts: 64
#     Tokens - min: 9, max: 27, mean: 15.4, median: 15.5
#   code:
#     Prompts: 64
#     Tokens - min: 9, max: 16, mean: 12.4, median: 11.5
#   sharegpt:
#     Prompts: 256
#     Tokens - min: 256, max: 763, mean: 458.5, median: 424.5
#   sonnet:
#     Prompts: 256
#     Tokens - min: 550, max: 550, mean: 550.0, median: 550.0
# ------------------------------------------------------------
#
# ✅ Loaded prompts from benchmark_prompts.json
#
# GPU: NVIDIA A100-SXM4-80GB (79.2 GB, CC 8.0)
# Dtype: bfloat16
# Batch sizes: [1, 8, 32, 64]
# Workloads: ['random_short', 'random_medium', 'long_context', 'mixed_context', 'shared_prefix', 'repetitive', 'code', 'sharegpt', 'sonnet']

# %% [markdown]
# ---
# ## 6. Test 1 — Baseline (RadixAttention ON)
#
# Starts a fresh SGLang server with default settings. RadixAttention is
# enabled by default, providing automatic prefix caching. This is SGLang's
# flagship optimization — requests sharing common prefixes reuse KV cache
# entries via a radix tree.

# %%
# --- Quick isolation test: code workload only ---
# Run this AFTER the initialization cell to test a single
# workload in isolation with a fresh server.

config_baseline = SGLANG_TEST_CONFIGS[0]  # baseline

df_code_only = run_single_config(
    config_baseline,
    batch_sizes=[1, 8],
    workload_names=["code"],
)
print(df_code_only[["workload_name", "batch_size", "throughput_output_tok_s",
                     "ttft_p50_ms", "successful_requests", "failed_requests"]])
# Out:
# ============================================================
# Workload: code — Code generation - tests structured output speculation
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 14:38:17] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=192626504, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 14:38:23] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 14:38:38] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 14:38:39] Init torch distributed ends. elapsed=0.77 s, mem usage=0.08 GB
#   [sglang] [2026-04-16
/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  86%|████████▌ | 50/58 [00:06<00:00, 17.99it/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=24 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=16 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.12it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.16it/s]
#   [sglang] Capturing num tokens (num_tokens=8 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.16it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.16it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00, 18.07it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00,  8.34it/s]
#   [sglang] [2026-04-16 14:40:06] Capture piecewise CUDA graph end. Time elapsed: 44.85 s. mem usage=0.95 GB. avail mem=5.55 GB.
#   [sglang] [2026-04-16 14:40:12] max_total_num_tokens=606631, chunked_prefill_size=8192, max_prefill_tokens=16384, max_running_requests=4096, context_len=8192, available_gpu_mem=5.55 GB
#   [sglang] [2026-04-16 14:40:13] INFO:     Started server process [2533]
#   [sglang] [2026-04-16 14:40:13] INFO:     Waiting for application startup.
#   [sglang] [2026-04-16 14:40:13] Using default chat sampling params from model generation config: {'temperature': 0.6, 'top_p': 0.9}
#   [sglang] [2026-04-16 14:40:13] INFO:     Application startup complete.
# ✅ sglang ready on port 8000
#   Warming up...
#     Batch    1 ... 0.0 tok/s  (0/1 ok)
#     Batch    8 ... 0.0 tok/s  (0/8 ok)
# 🧹 Stopping sglang on port 8000...
#
#   Saved 2 rows → results_baseline.csv
#   workload_name  batch_size  throughput_output_tok_s  ttft_p50_ms  \
# 0          code           1                      0.0          NaN
# 1          code           8                      0.0          NaN
#
#    successful_requests  failed_requests
# 0                    0                1
# 1                    0                8

# %%
print("=" * 60)
print("TEST 1: Baseline (RadixAttention ON)")
print("=" * 60)

config_baseline = SGLANG_TEST_CONFIGS[0]  # "baseline"
df_baseline = run_single_config(config_baseline)

df_baseline.to_csv("results_sglang_baseline.csv", index=False)
print(f"\nSaved {len(df_baseline)} rows -> results_sglang_baseline.csv")
df_baseline
# Out:
# ============================================================
# TEST 1: Baseline (RadixAttention ON)
# ============================================================
#
# ============================================================
# Workload: random_short — Short prompts (<100 tokens) - tests raw decode speed
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 14:42:49] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=157773373, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 14:42:55] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 14:43:11] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 14:43:11] Init torch distributed ends. elapsed=0.63 s, mem usage=0.08 GB
#   [sglang] [2026-04-16 14:43:15] Load weight begin. avail mem=78.74 GB
#   [sglang] [2026-04-16 14:43:15] Found local HF snapshot for meta-llama/Llama-3.2-3B-Instruct at /root/.cache/huggingface/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95; skipping download.
#   [sglang]
#   [sglang] Multi-thread loading shards:   0% Completed | 0/2 [00:00<?, ?it/s]
#   [sglang] Multi-thread loading shards:  50% Completed | 1/2 [00:01<00:01,  1.37s/it]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:02<00:00,  1.04it/s]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:02<00:00,  1.02s/it]
#   [sglang] [2026-04-16 14:43:17] Load weight end. elapsed=2.73 s, type=LlamaForCausalLM, avail mem=72.67 GB, mem usage=6.06 GB.
#   [sglang] [2026-04-16 14:43:17] Using KV cache dtype: torch.bfloat16
#   [sglang] [2026-04-16 14:43:17] KV Cache is allocated. #tokens: 606631, K size: 32.40 GB, V size: 32.40 GB
#   [sglang] [2026-04-16 14:43:17] Memory pool end. avail mem=7.68 GB
#   [sglang] [2026-04-16 14:43:18] Capture cuda graph begin. This can take up to several minutes. avail mem=7.25 GB
#   [sglang] [2026-04-16 14:43:18] Capture cuda graph bs [1, 2, 4, 8, 12, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256]
#   [sglang]
#   [sglang]   0%|          | 0/36 [00:00<?, ?it/s]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   0%|          | 0/36 [00:00<?, ?it/s]2026-04-16 14:43:20,167 - CUTE_DSL - WARNING - [handle_import_error] - Unexpected error during package walk: cutlass.cute.experimental
#   [sglang] [2026-04-16 14:43:20] Unexpected error during package walk: cutlass.cute.experimental
#   [sglang]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   3%|▎         | 1/36 [00:02<01:39,  2.83s/it]
#   [sglang] Capturing batches (bs=248 avail_mem=6.98 GB):   3%|▎         | 1/36 [00:02<01:39,  2.83s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   3%|▎         | 1/36 [00:02<01:39,  2.83s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.28it/s]
#   [sglang] Capturing batches (bs=232 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.28it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):   8%|▊         | 3/36 [00:03<00:25,  1.28it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.41it/s]
#   [sglang] Capturing batches (bs=216 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.41it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.41it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.76it/s]
#   [sglang] Capturing batches (bs=200 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.76it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.76it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.27it/s]
#   [sglang] Capturing batches (bs=184 avail_mem=6.89 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.27it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.27it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  31%|███       | 11/36 [00:03<00:03,  6.89it/s]
#   [sglang] Capturing batches (bs=168 avail_mem=6.86 GB):  31%|███       | 11/36 [00:03<00:03,  6.89it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  31%|███       | 11/36 [00:03<00:03,  6.89it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.50it/s]
#   [sglang] Capturing batches (bs=152 avail_mem=6.83 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.50it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.50it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.05it/s]
#   [sglang] Capturing batches (bs=136 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.05it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.05it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.46it/s]
#   [sglang] Capturing batches (bs=120 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.46it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.46it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.53it/s]
#   [sglang] Capturing batches (bs=104 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.53it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  53%|█████▎    | 19/36 [00:04<00:01, 12.53it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.51it/s]
#   [sglang] Capturing batches (bs=88 avail_mem=6.72 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.51it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.51it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.12it/s]
#   [sglang] Capturing batches (bs=72 avail_mem=6.69 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.12it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.12it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=56 avail_mem=6.66 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.11it/s]
#   [sglang] Capturing batches (bs=40 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.11it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.11it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.53it/s]
#   [sglang] Capturing batches (bs=24 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.53it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  81%|████████  | 29/36 [00:04<00:00, 15.53it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  86%|████████▌ | 31/36 [00:04<00:00, 13.94it/s]
#   [sglang] Capturing batches (bs=12 avail_mem=6.58 GB):  86%|████████▌ | 31/36 [00:04<00:00, 13.94it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  86%|████████▌ | 31/36 [00:04<00:00, 13.94it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.54it/s]
#   [sglang] Capturing batches (bs=4 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.54it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14
/s]
#   [sglang] Compiling num tokens (num_tokens=1280):  34%|███▍      | 20/58 [00:09<00:03, 12.20it/s]
#   [sglang] Compiling num tokens (num_tokens=1024):  34%|███▍      | 20/58 [00:09<00:03, 12.20it/s]
#   [sglang] Compiling num tokens (num_tokens=960):  34%|███▍      | 20/58 [00:09<00:03, 12.20it/s]
#   [sglang] Compiling num tokens (num_tokens=896):  34%|███▍      | 20/58 [00:09<00:03, 12.20it/s]
#   [sglang] Compiling num tokens (num_tokens=896):  40%|███▉      | 23/58 [00:09<00:02, 16.28it/s]
#   [sglang] Compiling num tokens (num_tokens=832):  40%|███▉      | 23/58 [00:09<00:02, 16.28it/s]
#   [sglang] Compiling num tokens (num_tokens=768):  40%|███▉      | 23/58 [00:09<00:02, 16.28it/s]
#   [sglang] Compiling num tokens (num_tokens=704):  40%|███▉      | 23/58 [00:09<00:02, 16.28it/s]
#   [sglang] Compiling num tokens (num_tokens=640):  40%|███▉      | 23/58 [00:09<00:02, 16.28it/s]
#   [sglang] Compiling num tokens (num_tokens=640):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=576):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=512):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=480):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=448):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=416):  47%|████▋     | 27/58 [00:09<00:01, 21.30it/s]
#   [sglang] Compiling num tokens (num_tokens=416):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=384):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=352):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=320):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=288):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=256):  55%|█████▌    | 32/58 [00:09<00:00, 28.13it/s]
#   [sglang] Compiling num tokens (num_tokens=256):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=240):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=224):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=208):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=192):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=176):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=160):  64%|██████▍   | 37/58 [00:09<00:00, 33.71it/s]
#   [sglang] Compiling num tokens (num_tokens=160):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=144):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=128):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=112):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=96):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=80):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=64):  74%|███████▍  | 43/58 [00:09<00:00, 38.92it/s]
#   [sglang] Compiling num tokens (num_tokens=64):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=48):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=32):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=28):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=24):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=20):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=16):  84%|████████▍ | 49/58 [00:09<00:00, 42.60it/s]
#   [sglang] Compiling num tokens (num_tokens=16):  95%|█████████▍| 55/58 [00:09<00:00, 45.91it/s]
#   [sglang] Compiling num tokens (num_tokens=12):  95%|█████████▍| 55/58 [00:09<00:00, 45.91it/s]
#   [sglang] Compiling num tokens (num_tokens=8):  95%|█████████▍| 55/58 [00:09<00:00, 45.91it/s]
#   [sglang] Compiling num tokens (num_tokens=4):  95%|█████████▍| 55/58 [00:09<00:00, 45.91it/s]
#   [sglang] Compiling num tokens (num_tokens=4): 100%|██████████| 58/58 [00:09<00:00,  5.88it/s]
#   [sglang]
#   [sglang]   0%|          | 0/58 [00:00<?, ?it/s]
#   [sglang] Capturing num tokens (num_tokens=8192 avail_mem=5.86 GB):   0%|          | 0/58 [00:00<?, ?it/s]
#   [sglang] Capturing num tokens (num_tokens=8192 avail_mem=5.86 GB):   2%|▏         | 1/58 [00:00<00:32,  1.75it/s]
#   [sglang] Capturing num tokens (num_tokens=7680 avail_mem=5.71 GB):   2%|▏         | 1/58 [00:00<00:32,  1.75it/s]
#   [sglang] Capturing num tokens (num_tokens=7680 avail_mem=5.71 GB):   3%|▎         | 2/58 [00:01<00:30,  1.87it/s]
#   [sglang] Capturing num tokens (num_tokens=7168 avail_mem=5.71 GB):   3%|▎         | 2/58 [00:01<00:30,  1.87it/s]
#   [sglang] Capturing num tokens (num_tokens=7168 avail_mem=5.71 GB):   5%|▌         | 3/58 [00:01<00:27,  1.99it/s]
#   [sglang] Capturing num tokens (num_tokens=6656 avail_mem=5.71 GB):   5%|▌         | 3/58 [00:01<00:27,  1.99it/s]
#   [sglang] Capturing num tokens (num_tokens=6656 avail_mem=5.71 GB):   7%|▋         | 4/58 [00:01<00:25,  2.14it/s]
#   [sglang] Capturing num tokens (num_tokens=6144 avail_mem=5.71 GB):   7%|▋         | 4/58 [00:01<00:25,  2.14it/s]
#   [sglang] Capturing num tokens (num_tokens=6144 avail_mem=5.71 GB):   9%|▊         | 5/58 [00:02<00:22,  2.33it/s]
#   [sglang] Capturing num tokens (num_tokens=5632 avail_mem=5.72 GB):   9%|▊         | 5/58 [00:02<00:22,  2.33it/s]
#   [sglang] Capturing num tokens (num_tokens=5632 avail_mem=5.72 GB):  10%|█         | 6/58 [00:02<00:20,  2.54it/s]
#   [sglang] Capturing num tokens (num_tokens=5120 avail_mem=5.72 GB):  10%|█         | 6/58 [00:02<00:20,  2.54it/s]
#   [sglang] Capturing num tokens (num_tokens=5120 avail_mem=5.72 GB):  12%|█▏        | 7/58 [00:02<00:18,  2.80it/s]
#   [sglang] Capturing num tokens (num_tokens=4608 avail_mem=5.72 GB):  12%|█▏        | 7/58 [00:02<00:18,  2.80it/s]
#   [sglang] Capturing num tokens (num_tokens=4608 avail_mem=5.72 GB):  14%|█▍        | 8/58 [00:03<00:16,  3.11it/s]
#   [sglang] Capturing num tokens (num_tokens=4096 avail_mem=5.72 GB):  14%|█▍        | 8/58 [00:03<00:16,  3.11it/s]
#   [sglang] Capturing num tokens (num_tokens=4096 avail_mem=5.72 GB):  16%|█▌        | 9/58 [00:03<00:14,  3.49it/s]
#   [sglang] Capturing num tokens (num_tokens=3840 avail_mem=5.73 GB):  16%|█▌        | 9/58 [00:03<00:14,  3.49it/s]
#   [sglang] Capturing num tokens (num_tokens=3840 avail_mem=5.73 GB):  17%|█▋        | 10/58 [00:03<00:12,  3.86it/s]
#   [sglang] Capturing num tokens (num_tokens=3584 avail_mem=5.72 GB):  17%|█▋        | 10/58 [00:03<00:12,  3.86it/s]
#   [sglang] Capturing num tokens (num_tokens=3584 avail_mem=5.72 GB):  19%|█▉        | 11/58 [00:03<00:11,  4.23it/s]
#   [sglang] Capturing num tokens (num_tokens=3328 avail_mem=5.72 GB):  19%|█▉        | 11/58 [00:03<00:11,  4.23it/s]
#   [sglang] Capturing num tokens (num_tokens=3328 avail_mem=5.72 GB):  21%|██        | 12/58 [00:03<00:09,  4.67it/s]
#   [sglang] Capturing num tokens (num_tokens=3072 avail_mem=5.72 GB):  21%|██        | 12/58 [00:03<00:09,  4.67it/s]
#   [sglang] Capturing num tokens (num_tokens=3072 avail_mem=5.72 GB):  22%|██▏       | 13/58 [00:04<00:08,  5.10it/s]
#   [sglang] Capturing num tokens (num_tokens=2816 avail_mem=5.72 GB):  22%|██▏       | 13/58 [00:04<00:08,  5.10it/s]
#   [sglang] Capturing num tokens (num_tokens=2816 avail_mem=5.72 GB):  24%|██▍       | 14/58 [00:04<00:07,  5.58it/s]
#   [sglang] Capturing num tokens (num_tokens=2560 avail_mem=5.71 GB):  24%|██▍       | 14/58 [00:04<00:07,  5.58it/s]
#   [sglang] Capturing num tokens (num_tokens=2560 avail_mem=5.71 GB):  26%|██▌       | 15/58 [00:04<00:06,  6.15it/s]
#   [sglang] Capturing num tokens (num_tokens=2304 avail_mem=5.71 GB):  26%|██▌       | 15/58 [00:04<00:06,  6.15it/s]
#   [sglang] Capturing num tokens (num_tokens=2304 avail_mem=5.71 GB):  28%|██▊       | 16/58 [00:04<00:06,  6.84it/s]
#   [sglang] Capturing num tokens (num_tokens=2048 avail_mem=5.71 GB):  28%|██▊       | 16/58 [00:04<00:06,  6.84it/s]
#   [sglang] Capturing num tokens (num_tokens=1792 avail_mem=5.71 GB):  28%|██▊       | 16/58 [00:04<00:06,  6.84it/s]
#   [sglang] Capturing num tokens (num_tokens=1792 avail_mem=5.71 GB):  31%|███       | 18/58 [00:04<00:04,  8.18it/s]
#   [sglang] Capturing num tokens (num_tokens=1536 avail_mem=5.72 GB):  31%|███       | 18/58 [00:04<00:04,  8.18it/s]
#   [sglang] Capturing num tokens (num_tokens=1280 avail_mem=5.71 GB):  31%|███       | 18/58 [00:04<00:04,  8.18it/s]
#   [sglang] Capturing num tokens (num_tokens=1280 avail_mem=5.71 GB):  34%|███▍      | 20/58 [00:04<00:04,  9.50it/s]
#   [sglang] Capturing num tokens (num_tokens=1024 avail_mem=5.71 GB):  34%|███▍      | 20/58 [00:04<00:04,  9.50it/s]
#   [sglang] Capturing num tokens (num_tokens=960 avail_mem=5.70 GB):  34%|███▍      | 20/58 [00:04<00:04,  9.50it/s]
#   [sglang] Capturing num tokens (num_tokens=960 avail_mem=5.70 GB):  38%|███▊      | 22/58 [00:04<00:03, 11.08it/s]
#   [sglang] Capturing num tokens (num_tokens=896 avail_mem=5.72 GB):  38%|███▊      | 22/58 [00:04<00:03, 11.08it/s]
#   [sglang] Capturing num tokens (num_tokens=832 avail_mem=5.71 GB):  38%|███▊      | 22/58 [00:04<00:03, 11.08it/s]
#   [sglang] Capturing num tokens (num_tokens=832 avail_mem=5.71 GB):  41%|████▏     | 24/58 [00:05<00:02, 12.35it/s]
#   [sglang] Capturing num tokens (num_tokens=768 avail_mem=5.71 GB):  41%|████▏     | 24/58 [00:05<00:02, 12.35it/s]
#   [sglang] Capturing num tokens (num_tokens=704 avail_mem=5.70 GB):  41%|████▏     | 24/58 [00:05<00:02, 12.35it/s]
#   [sglang] Capturing num tokens (num_tokens=704 avail_mem=5.70 GB):  45%|████▍     | 26/58 [00:05<00:02, 13.51it/s]
#   [sglang] Capturing num tokens (num_tokens=640 avail_mem=5.70 GB):  45%|████▍     | 26/58 [00:05<00:02, 13.51it/s]
#   [sglang] Capturing num tokens (num_tokens=576 avail_mem=5.69 GB):  45%|████▍     | 26/58 [00:05<00:02, 13.51it/s]
#   [sglang] Capturing num tokens (num_tokens=576 avail_mem=5.69 GB):  48%|████▊     | 28/58 [00:05<00:02, 14.68it/s]
#   [sglang] Capturing num tokens (num_tokens=512 avail_mem=5.69 GB):  48%|████▊     | 28/58 [00:05<00:02, 14.68it/s]
#   [sglang] Capturing num tokens (num_tokens=480 avail_mem=5.69 GB):  48%|████▊     | 28/58 [00:05<00:02, 14.68it/s]
#   [sglang] Capturing num tokens (num_tokens=480 avail_mem=5.69 GB):  52%|█████▏    | 30/58 [00:05<00:01, 15.58it/s]
#   [sglang] Capturing num tokens (num_tokens=448 avail_mem=5.68 GB):  52%|█████▏    | 30/58 [00:05<00:01, 15.58it/s]
#   [sglang] Capturing num tokens (num_tokens=416 avail_mem=5.68 GB):  52%|█████▏    | 30/58 [00:05<00:01, 15.58it/s]
#   [sglang] Capturing num tokens (num_tokens=416 avail_mem=5.68 GB):  55%|█████▌    | 32/58 [00:05<00:01, 16.43it/s]
#   [sglang] Capturing num tokens (num_tokens=384 avail_mem=5.67 GB):  55%|█████▌    | 32/58 [00:05<00:01, 16.43it/s]
#   [sglang] Capturing num tokens (num_tokens=352 avail_mem=5.67 GB):  55%|█████▌    | 32/58 [00:05<00:01, 16.43it/s]
#   [sglang] Capturing num tokens (num_tokens=352 avail_mem=5.67 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.10it/s]
#   [sglang] Capturing num tokens (num_tokens=320 avail_mem=5.66 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.10it/s]
#   [sglang] Capturing num tokens (num_tokens=288 avail_mem=5.66 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.10it/s]
#   [sglang] Capturing num tokens (num_tokens=288 avail_mem=5.66 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.58it/s]
#   [sglang] Capturing num tokens (num_tokens=256 avail_mem=5.66 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.58it/s]
#   [sglang] Capturing num tokens (num_tokens=240 avail_mem=5.65 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.58it/s]
#   [sglang] Capturing num tokens (num_tokens=240 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.90it/s]
#   [sglang] Capturing num tokens (num_tokens=224 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.90it/s]
#   [sglang] Capturing num tokens (num_tokens=208 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.90it/s]
#   [sglang] Capturing num tokens (num_tokens=208 avail_mem=5.65 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=192 avail_mem=5.64 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=176 avail_mem=5.64 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=176 avail_mem=5.64 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.21it/s]
#   [sglang] Capturing num tokens (num_tokens=160 avail_mem=5.63 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.21it/s]
#   [sglang] Capturing num tokens (num_tokens=144 avail_mem=5.62 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.21it/s]
#   [sglang] Capturing num tokens (num_tokens=144 avail_mem=5.62 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=128 avail_mem=5.62 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=112 avail_mem=5.61 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=112 avail_mem=5.61 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.36it/s]
#   [sglang] Capturing num tokens (num_tokens=96 avail_mem=5.61 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.36it/s]
#   [sglang] Capturing num tokens (num_tokens=80 avail_mem=5.60 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.36it/s]
#   [sglang] Capturing num tokens (num_tokens=80 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.55it/s]
#   [sglang] Capturing num tokens (num_tokens=64 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.55it/s]
#   [sglang] Capturing num tokens (num_tokens=48 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.55it/s]
#   [sglang] Capturing num tokens (num_tokens=48 avail_mem=5.60 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.80it/s]
#   [sglang] Capturing num tokens (num_tokens=32 avail_mem=5.59 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.80it/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.80it/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  90%|████████▉ | 52/58 [00:06<00:00, 19.00it/s]
#   [sglang] Capturing num tokens (num_tokens=24 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 19.00it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 19.00it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.97it/s]
#   [sglang] Capturing num tokens (num_tokens=16 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.97it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.97it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.84it/s]
#   [sglang] Capturing num tokens (num_tokens=8 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.84it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.84it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00, 18.74it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00,  8.42it/s]
#   [sglang] [2026-04-16 14:43:41] Capture piecewise CUDA graph end. Time elapsed: 17.37 s. mem usage=0.95 GB. avail mem=5.55 GB.
#   [sglang] [2026-04-16 14:43:47] max_total_num_tokens=606631, chunked_prefill_size=8192, max_prefill_tokens=16384, max_running_requests=4096, context_len=8192, available_gpu_mem=5.55 GB
#   [sglang] [2026-04-16 14:43:48] INFO:     Started server process [4493]
#   [sglang] [2026-04-16 14:43:48] INFO:     Waiting for application startup.
#   [sglang] [2026-04-16 14:43:48] Using default chat sampling params from model generation config: {'temperature': 0.6, 'top_p': 0.9}
#   [sglang] [2026-04-16 14:43:48] INFO:     Application startup complete.
# ✅ sglang ready on port 8000
#   Warming up...
#     Batch    1 ... 162.0 tok/s  (1/1 ok)
#     Batch    8 ... 875.2 tok/s  (8/8 ok)
#     Batch   32 ... 4,056.6 tok/s  (32/32 ok)
#     Batch   64 ... 5,036.1 tok/s  (64/64 ok)
# 🧹 Stopping sglang on port 8000...
#
# ============================================================
# Workload: random_medium — Medium prompts (100-500 tokens) - balanced workload
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 14:44:15] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=957869302, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 14:44:21] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 14:44:36] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 14:44:37] Init torch distributed ends. elapsed=0.90 s, mem usage=0.08 GB
#   [sglang] [2026-04-16 14:44:40] Load weight begin. avail mem=78.74 GB
#   [sglang] [2026-04-16 14:44:41] Found local HF snapshot for meta-llama/Llama-3.2-3B-Instruct at /root/.cache/huggingface/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95; skipping download.
#   [sglang]
#   [sglang] Multi-thread loading shards:   0% Completed | 0/2 [00:00<?, ?it/s]
#   [sglang] Multi-thread loading shards:  50% Completed | 1/2 [00:01<00:01,  1.36s/it]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.17it/s]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.07it/s]
#   [sglang] [2026-04-16 14:44:43] Load weight end. elapsed=2.51 s, type=LlamaForCausalLM, avail mem=72.67 GB, mem usage=6.06 GB.
#   [sglang] [2026-04-16 14:44:43] Using KV cache dtype: torch.bfloat16
#   [sglang] [2026-04-16 14:44:43] KV Cache is allocated. #tokens: 606631, K size: 32.40 GB, V size: 32.40 GB
#   [sglang] [2026-04-16 14:44:43] Memory pool end. avail mem=7.68 GB
#   [sglang] [2026-04-16 14:44:43] Capture cuda graph begin. This can take up to several minutes. avail mem=7.25 GB
#   [sglang] [2026-04-16 14:44:43] Capture cuda graph bs [1, 2, 4, 8, 12, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256]
#   [sglang]
#   [sglang]   0%|          | 0/36 [00:00<?, ?it/s]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   0%|          | 0/36 [00:00<?, ?it/s]2026-04-16 14:44:45,711 - CUTE_DSL - WARNING - [handle_import_error] - Unexpected error during package walk: cutlass.cute.experimental
#   [sglang] [2026-04-16 14:44:45] Unexpected error during package walk: cutlass.cute.experimental
#   [sglang]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   3%|▎         | 1/36 [00:02<01:38,  2.80s/it]
#   [sglang] Capturing batches (bs=248 avail_mem=6.98 GB):   3%|▎         | 1/36 [00:02<01:38,  2.80s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   3%|▎         | 1/36 [00:02<01:38,  2.80s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=232 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=216 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=200 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.40it/s]
#   [sglang] Capturing batches (bs=184 avail_mem=6.89 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.40it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.40it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  31%|███       | 11/36 [00:03<00:03,  7.07it/s]
#   [sglang] Capturing batches (bs=168 avail_mem=6.86 GB):  31%|███       | 11/36 [00:03<00:03,  7.07it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  31%|███       | 11/36 [00:03<00:03,  7.07it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.70it/s]
#   [sglang] Capturing batches (bs=152 avail_mem=6.83 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.70it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.70it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.26it/s]
#   [sglang] Capturing batches (bs=136 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.26it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.26it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.72it/s]
#   [sglang] Capturing batches (bs=120 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.72it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.72it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.94it/s]
#   [sglang] Capturing batches (bs=104 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.94it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.94it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.96it/s]
#   [sglang] Capturing batches (bs=88 avail_mem=6.72 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.96it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.96it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=72 avail_mem=6.69 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.68it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.06it/s]
#   [sglang] Capturing batches (bs=56 avail_mem=6.66 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.06it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.06it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.39it/s]
#   [sglang] Capturing batches (bs=40 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.39it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.39it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.70it/s]
#   [sglang] Capturing batches (bs=24 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.70it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  81%|████████  | 29/36 [00:04<00:00, 15.70it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.10it/s]
#   [sglang] Capturing batches (bs=12 avail_mem=6.58 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.10it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.10it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.79it/s]
#   [sglang] Capturing batches (bs=4 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.79it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.79it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.56it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.56it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 G
# 4     baseline  random_medium           1                   167.36
# 5     baseline  random_medium           8                   583.29
# 6     baseline  random_medium          32                  1891.74
# 7     baseline  random_medium          64                  2728.30
# 8     baseline   long_context           1                   142.11
# 9     baseline   long_context           8                   660.94
# 10    baseline   long_context          32                  1996.15
# 11    baseline  mixed_context           1                   149.15
# 12    baseline  mixed_context           8                   424.91
# 13    baseline  mixed_context          32                  1068.06
# 14    baseline  shared_prefix           1                   168.00
# 15    baseline  shared_prefix           8                  1095.15
# 16    baseline  shared_prefix          32                  3567.65
# 17    baseline     repetitive           1                   171.09
# 18    baseline     repetitive           8                   980.86
# 19    baseline           code           1                   177.60
# 20    baseline           code           8                  1272.28
# 21    baseline           code          32                  4527.77
# 22    baseline           code          64                  5635.27
# 23    baseline       sharegpt           1                   168.42
# 24    baseline       sharegpt           8                   962.98
# 25    baseline       sharegpt          32                  3147.86
# 26    baseline       sharegpt          64                  4635.53
# 27    baseline         sonnet           1                   167.14
# 28    baseline         sonnet           8                  1060.49
# 29    baseline         sonnet          32                  2879.77
# 30    baseline         sonnet          64                  3931.79
#
#     throughput_total_tok_s  ttft_p50_ms  ttft_p95_ms  ttft_p99_ms  ...  \
# 0                   170.50        19.27        19.27        19.27  ...
# 1                   891.81       173.23       175.07       175.17  ...
# 2                  4126.06        76.22        82.81        83.69  ...
# 3                  5120.67       622.99       815.39       817.72  ...
# 4                   175.94        19.67        19.67        19.67  ...
# 5                   602.49        57.08        60.17        60.54  ...
# 6                  1957.94       120.12       131.41       132.49  ...
# 7                  2812.82       641.52       774.97       776.14  ...
# 8                   153.96        34.70        34.70        34.70  ...
# 9                   677.70       120.24       131.63       132.20  ...
# 10                 2043.50       226.01       424.40       426.94  ...
# 11                  149.94       228.13       228.13       228.13  ...
# 12                  428.85       425.14       658.87       659.20  ...
# 13                 1077.30      1274.43      2471.11      2490.05  ...
# 14                  171.54        27.30        27.30        27.30  ...
# 15                 1119.76        52.42        56.94        57.40  ...
# 16                 3647.93       105.76       111.60       112.56  ...
# 17                  174.35        20.02        20.02        20.02  ...
# 18                 1000.47        42.65        44.85        45.06  ...
# 19                  180.36        23.24        23.24        23.24  ...
# 20                 1292.00        40.75        43.07        43.21  ...
# 21                 4597.96        79.38        86.71        87.70  ...
# 22                 5722.64       607.00       798.94       800.43  ...
# 23                  170.15        30.88        30.88        30.88  ...
# 24                  967.69       110.12       121.52       121.95  ...
# 25                 3163.36       217.49       362.76       365.08  ...
# 26                 4658.12       769.82       923.85       929.82  ...
# 27                  169.35        32.10        32.10        32.10  ...
# 28                 1074.54       130.58       150.93       151.49  ...
# 29                 2917.91       246.78       455.91       458.30  ...
# 30                 3983.86       788.19       954.47       962.40  ...
#
#     goodput_goodput_requests_s  goodput_success_rate  goodput_timeout_rate  \
# 0                        4.263                 100.0                   0.0
# 1                        8.325                 100.0                   0.0
# 2                       34.727                 100.0                   0.0
# 3                       42.298                 100.0                   0.0
# 4                        4.291                 100.0                   0.0
# 5                        9.602                 100.0                   0.0
# 6                         100.0                  NaN
# 7                           0.0                  NaN
# 8                         100.0                  NaN
# 9                         100.0                  NaN
# 10                        100.0                  NaN
# 11                        100.0                  NaN
# 12                         50.0                  NaN
# 13                          0.0                  NaN
# 14                        100.0                  NaN
# 15                        100.0                  NaN
# 16                        100.0                  NaN
# 17                        100.0                  NaN
# 18                        100.0                  NaN
# 19                        100.0                  NaN
# 20                        100.0                  NaN
# 21                        100.0                  NaN
# 22                          0.0                  NaN
# 23                        100.0                  NaN
# 24                        100.0                  NaN
# 25                        100.0                  NaN
# 26                          0.0                  NaN
# 27                        100.0                  NaN
# 28                        100.0                  NaN
# 29                        100.0                  NaN
# 30                          0.0                  NaN
#
# [31 rows x 32 columns]

# %% [markdown]
# ## 7. Test 2 — No RadixAttention (Prefix Caching Disabled)
#
# Starts a fresh SGLang server with `--disable-radix-cache`. This disables
# SGLang's automatic prefix caching, providing a direct comparison to measure
# RadixAttention's benefit — especially visible on the `shared_prefix` workload.

# %%
print("=" * 60)
print("TEST 2: No RadixAttention (prefix caching disabled)")
print("=" * 60)

config_no_radix = SGLANG_TEST_CONFIGS[1]  # "no_radix"
df_no_radix = run_single_config(config_no_radix)

df_no_radix.to_csv("results_sglang_no_radix.csv", index=False)
print(f"\nSaved {len(df_no_radix)} rows -> results_sglang_no_radix.csv")
df_no_radix
# Out:
# ============================================================
# TEST 2: No RadixAttention (prefix caching disabled)
# ============================================================
#
# ============================================================
# Workload: random_short — Short prompts (<100 tokens) - tests raw decode speed
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --disable-radix-cache --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 14:55:59] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=573125020, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 14:56:05] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 14:56:20] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 14:56:21] Init torch distributed ends. elapsed=0.41 s, mem usage=0.08 GB
#   [sglang] [2026-04-16 14:56:24] Load weight begin. avail mem=78.74 GB
#   [sglang] [2026-04-16 14:56:24] Found local HF snapshot for meta-llama/Llama-3.2-3B-Instruct at /root/.cache/huggingface/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95; skipping download.
#   [sglang]
#   [sglang] Multi-thread loading shards:   0% Completed | 0/2 [00:00<?, ?it/s]
#   [sglang] Multi-thread loading shards:  50% Completed | 1/2 [00:01<00:01,  1.37s/it]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.18it/s]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.08it/s]
#   [sglang] [2026-04-16 14:56:27] Load weight end. elapsed=2.51 s, type=LlamaForCausalLM, avail mem=72.67 GB, mem usage=6.06 GB.
#   [sglang] [2026-04-16 14:56:27] Using KV cache dtype: torch.bfloat16
#   [sglang] [2026-04-16 14:56:27] KV Cache is allocated. #tokens: 606631, K size: 32.40 GB, V size: 32.40 GB
#   [sglang] [2026-04-16 14:56:27] Memory pool end. avail mem=7.68 GB
#   [sglang] [2026-04-16 14:56:27] Capture cuda graph begin. This can take up to several minutes. avail mem=7.25 GB
#   [sglang] [2026-04-16 14:56:27] Capture cuda graph bs [1, 2, 4, 8, 12, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256]
#   [sglang]
#   [sglang]   0%|          | 0/36 [00:00<?, ?it/s]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   0%|          | 0/36 [00:00<?, ?it/s]2026-04-16 14:56:29,236 - CUTE_DSL - WARNING - [handle_import_error] - Unexpected error during package walk: cutlass.cute.experimental
#   [sglang] [2026-04-16 14:56:29] Unexpected error during package walk: cutlass.cute.experimental
#   [sglang]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   3%|▎         | 1/36 [00:02<01:37,  2.78s/it]
#   [sglang] Capturing batches (bs=248 avail_mem=6.98 GB):   3%|▎         | 1/36 [00:02<01:37,  2.78s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   3%|▎         | 1/36 [00:02<01:37,  2.78s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=232 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.46it/s]
#   [sglang] Capturing batches (bs=216 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.46it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.46it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.84it/s]
#   [sglang] Capturing batches (bs=200 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.84it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.84it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.41it/s]
#   [sglang] Capturing batches (bs=184 avail_mem=6.89 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.41it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.41it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  31%|███       | 11/36 [00:03<00:03,  7.08it/s]
#   [sglang] Capturing batches (bs=168 avail_mem=6.86 GB):  31%|███       | 11/36 [00:03<00:03,  7.08it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  31%|███       | 11/36 [00:03<00:03,  7.08it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.74it/s]
#   [sglang] Capturing batches (bs=152 avail_mem=6.83 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.74it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.74it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.27it/s]
#   [sglang] Capturing batches (bs=136 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.27it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.27it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.66it/s]
#   [sglang] Capturing batches (bs=120 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.66it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.66it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.85it/s]
#   [sglang] Capturing batches (bs=104 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.85it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.85it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=88 avail_mem=6.72 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.44it/s]
#   [sglang] Capturing batches (bs=72 avail_mem=6.69 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.44it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.44it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.91it/s]
#   [sglang] Capturing batches (bs=56 avail_mem=6.66 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.91it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  69%|██████▉   | 25/36 [00:04<00:00, 14.91it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.38it/s]
#   [sglang] Capturing batches (bs=40 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.38it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.38it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.81it/s]
#   [sglang] Capturing batches (bs=24 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.81it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  81%|████████  | 29/36 [00:04<00:00, 15.81it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.17it/s]
#   [sglang] Capturing batches (bs=12 avail_mem=6.58 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.17it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.17it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.80it/s]
#   [sglang] Capturing batches (bs=4 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.80it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.80it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.20it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.20it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 GB): 100%|██████████| 36/36 [00:05<00:00,  7.20it/s]
#   [sglang] [2026-04-16 14:56:33] Capture cuda graph end. Time elapsed: 5.99 s. mem usage=0.75 GB. avail mem=6.50 GB.
#   [sglang] [2026-04-16 14:56:33] Capture piecewise CUDA graph begin. avail mem=6.50 GB
#   [sglang] [2026-04-16 14:56:33] Capture cuda graph num tokens [4, 8, 12, 16, 20, 24, 28, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240,
avail_mem=5.67 GB):  55%|█████▌    | 32/58 [00:05<00:01, 16.72it/s]
#   [sglang] Capturing num tokens (num_tokens=352 avail_mem=5.67 GB):  55%|█████▌    | 32/58 [00:05<00:01, 16.72it/s]
#   [sglang] Capturing num tokens (num_tokens=352 avail_mem=5.67 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.27it/s]
#   [sglang] Capturing num tokens (num_tokens=320 avail_mem=5.66 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.27it/s]
#   [sglang] Capturing num tokens (num_tokens=288 avail_mem=5.66 GB):  59%|█████▊    | 34/58 [00:05<00:01, 17.27it/s]
#   [sglang] Capturing num tokens (num_tokens=288 avail_mem=5.66 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.74it/s]
#   [sglang] Capturing num tokens (num_tokens=256 avail_mem=5.66 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.74it/s]
#   [sglang] Capturing num tokens (num_tokens=240 avail_mem=5.65 GB):  62%|██████▏   | 36/58 [00:05<00:01, 17.74it/s]
#   [sglang] Capturing num tokens (num_tokens=240 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.85it/s]
#   [sglang] Capturing num tokens (num_tokens=224 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.85it/s]
#   [sglang] Capturing num tokens (num_tokens=208 avail_mem=5.65 GB):  66%|██████▌   | 38/58 [00:05<00:01, 17.85it/s]
#   [sglang] Capturing num tokens (num_tokens=208 avail_mem=5.65 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=192 avail_mem=5.64 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=176 avail_mem=5.64 GB):  69%|██████▉   | 40/58 [00:05<00:00, 18.08it/s]
#   [sglang] Capturing num tokens (num_tokens=176 avail_mem=5.64 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.26it/s]
#   [sglang] Capturing num tokens (num_tokens=160 avail_mem=5.63 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.26it/s]
#   [sglang] Capturing num tokens (num_tokens=144 avail_mem=5.62 GB):  72%|███████▏  | 42/58 [00:06<00:00, 18.26it/s]
#   [sglang] Capturing num tokens (num_tokens=144 avail_mem=5.62 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=128 avail_mem=5.62 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=112 avail_mem=5.61 GB):  76%|███████▌  | 44/58 [00:06<00:00, 18.29it/s]
#   [sglang] Capturing num tokens (num_tokens=112 avail_mem=5.61 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.19it/s]
#   [sglang] Capturing num tokens (num_tokens=96 avail_mem=5.61 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.19it/s]
#   [sglang] Capturing num tokens (num_tokens=80 avail_mem=5.60 GB):  79%|███████▉  | 46/58 [00:06<00:00, 18.19it/s]
#   [sglang] Capturing num tokens (num_tokens=80 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.09it/s]
#   [sglang] Capturing num tokens (num_tokens=64 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.09it/s]
#   [sglang] Capturing num tokens (num_tokens=48 avail_mem=5.60 GB):  83%|████████▎ | 48/58 [00:06<00:00, 18.09it/s]
#   [sglang] Capturing num tokens (num_tokens=48 avail_mem=5.60 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.24it/s]
#   [sglang] Capturing num tokens (num_tokens=32 avail_mem=5.59 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.24it/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  86%|████████▌ | 50/58 [00:06<00:00, 18.24it/s]
#   [sglang] Capturing num tokens (num_tokens=28 avail_mem=5.59 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.33it/s]
#   [sglang] Capturing num tokens (num_tokens=24 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.33it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  90%|████████▉ | 52/58 [00:06<00:00, 18.33it/s]
#   [sglang] Capturing num tokens (num_tokens=20 avail_mem=5.58 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.34it/s]
#   [sglang] Capturing num tokens (num_tokens=16 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.34it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  93%|█████████▎| 54/58 [00:06<00:00, 18.34it/s]
#   [sglang] Capturing num tokens (num_tokens=12 avail_mem=5.57 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.32it/s]
#   [sglang] Capturing num tokens (num_tokens=8 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.32it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB):  97%|█████████▋| 56/58 [00:06<00:00, 18.32it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00, 18.24it/s]
#   [sglang] Capturing num tokens (num_tokens=4 avail_mem=5.56 GB): 100%|██████████| 58/58 [00:06<00:00,  8.40it/s]
#   [sglang] [2026-04-16 14:56:50] Capture piecewise CUDA graph end. Time elapsed: 17.29 s. mem usage=0.95 GB. avail mem=5.55 GB.
#   [sglang] [2026-04-16 14:56:56] max_total_num_tokens=606631, chunked_prefill_size=8192, max_prefill_tokens=16384, max_running_requests=4096, context_len=8192, available_gpu_mem=5.55 GB
#   [sglang] [2026-04-16 14:56:57] INFO:     Started server process [10169]
# ✅ sglang ready on port 8000
#   Warming up...
#     Batch    1 ... 174.4 tok/s  (1/1 ok)
#     Batch    8 ... 999.5 tok/s  (8/8 ok)
#     Batch   32 ... 4,035.6 tok/s  (32/32 ok)
#     Batch   64 ... 5,066.7 tok/s  (64/64 ok)
# 🧹 Stopping sglang on port 8000...
#
# ============================================================
# Workload: random_medium — Medium prompts (100-500 tokens) - balanced workload
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --disable-radix-cache --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 14:57:23] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=270318595, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 14:57:30] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 14:57:45] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 14:57:45] Init torch distributed ends. elapsed=0.41 s, mem usage=0.08 GB
#   [sglang] [2026-04-16 14:57:49] Load weight begin. avail mem=78.74 GB
#   [sglang] [2026-04-16 14:57:49] Found local HF snapshot for meta-llama/Llama-3.2-3B-Instruct at /root/.cache/huggingface/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95; skipping download.
#   [sglang]
#   [sglang] Multi-thread loading shards:   0% Completed | 0/2 [00:00<?, ?it/s]
#   [sglang] Multi-thread loading shards:  50% Completed | 1/2 [00:01<00:01,  1.40s/it]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.14it/s]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.05it/s]
#   [sglang] [2026-04-16 14:57:51] Load weight end. elapsed=2.54 s, type=LlamaForCausalLM, avail mem=72.67 GB, mem usage=6.06 GB.
#   [sglang] [2026-04-16 14:57:51] Using KV cache dtype: torch.bfloat16
#   [sglang] [2026-04-16 14:57:51] KV Cache is allocated. #tokens: 606631, K size: 32.40 GB, V size: 32.40 GB
#   [sglang] [2026-04-16 14:57:51] Memory pool end. avail mem=7.68 GB
#   [sglang] [2026-04-16 14:57:51] Capture cuda graph begin. This can take up to several minutes. avail mem=7.25 GB
#   [sglang] [2026-04-16 14:57:51] Capture cuda graph bs [1, 2, 4, 8, 12, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256]
#   [sglang]
#   [sglang]   0%|          | 0/36 [00:00<?, ?it/s]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   0%|          | 0/36 [00:00<?, ?it/s]2026-04-16 14:57:53,917 - CUTE_DSL - WARNING - [handle_import_error] - Unexpected error during package walk: cutlass.cute.experimental
#   [sglang] [2026-04-16 14:57:53] Unexpected error during package walk: cutlass.cute.experimental
#   [sglang]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   3%|▎         | 1/36 [00:02<01:37,  2.77s/it]
#   [sglang] Capturing batches (bs=248 avail_mem=6.98 GB):   3%|▎         | 1/36 [00:02<01:37,  2.77s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   3%|▎         | 1/36 [00:02<01:37,  2.77s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=232 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):   8%|▊         | 3/36 [00:02<00:25,  1.31it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.47it/s]
#   [sglang] Capturing batches (bs=216 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.47it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.47it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.86it/s]
#   [sglang] Capturing batches (bs=200 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.86it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.86it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.43it/s]
#   [sglang] Capturing batches (bs=184 avail_mem=6.89 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.43it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  25%|██▌       | 9/36 [00:03<00:04,  5.43it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  31%|███       | 11/36 [00:03<00:03,  7.09it/s]
#   [sglang] Capturing batches (bs=168 avail_mem=6.86 GB):  31%|███       | 11/36 [00:03<00:03,  7.09it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  31%|███       | 11/36 [00:03<00:03,  7.09it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.76it/s]
#   [sglang] Capturing batches (bs=152 avail_mem=6.83 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.76it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.76it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.32it/s]
#   [sglang] Capturing batches (bs=136 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.32it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.32it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.74it/s]
#   [sglang] Capturing batches (bs=120 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.74it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.74it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.90it/s]
#   [sglang] Capturing batches (bs=104 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.90it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.90it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  58%|█████▊    | 21/36 [00:03<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=88 avail_mem=6.72 GB):  58%|█████▊    | 21/36 [00:03<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.80it/s]
#   [sglang] Capturing batches (bs=80 avail_mem=6.70 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.47it/s]
#   [sglang] Capturing batches (bs=72 avail_mem=6.69 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.47it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  64%|██████▍   | 23/36 [00:04<00:00, 14.47it/s]
#   [sglang] Capturing batches (bs=64 avail_mem=6.67 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.01it/s]
#   [sglang] Capturing batches (bs=56 avail_mem=6.66 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.01it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  69%|██████▉   | 25/36 [00:04<00:00, 15.01it/s]
#   [sglang] Capturing batches (bs=48 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.46it/s]
#   [sglang] Capturing batches (bs=40 avail_mem=6.64 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.46it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  75%|███████▌  | 27/36 [00:04<00:00, 15.46it/s]
#   [sglang] Capturing batches (bs=32 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.80it/s]
#   [sglang] Capturing batches (bs=24 avail_mem=6.61 GB):  81%|████████  | 29/36 [00:04<00:00, 15.80it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  81%|████████  | 29/36 [00:04<00:00, 15.80it/s]
#   [sglang] Capturing batches (bs=16 avail_mem=6.59 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.11it/s]
#   [sglang] Capturing batches (bs=12 avail_mem=6.58 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.11it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  86%|████████▌ | 31/36 [00:04<00:00, 14.11it/s]
#   [sglang] Capturing batches (bs=8 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.77it/s]
#   [sglang] Capturing batches (bs=4 avail_mem=6.56 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.77it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  92%|█████████▏| 33/36 [00:04<00:00, 14.77it/s]
#   [sglang] Capturing batches (bs=2 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.49it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 GB):  97%|█████████▋| 35/36 [00:04<00:00, 14.49it/s]
#   [sglang] Capturing batches (bs=1 avail_mem=6.53 GB): 100%|██████████| 36/36 [00:04<00:00,  7.23it/s]
#   [sglang] [2026-04-16 14:57:57] Capture cuda graph end. Time elapsed: 5.96 s. mem usage=0.75 GB. avail mem=6.50 GB.
#   [sglang] [2026-04-16 14:57:57] Capture piecewise CUDA graph begin. avail mem=6.50 GB
#   [sglang] [2026-04-16 14:57:57] Capture cuda graph num tokens [4, 8, 12, 16, 20, 24, 28, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 288, 320, 352, 384, 416, 448, 480, 512, 576, 640, 704, 768, 832, 896, 960, 1024, 1280, 1536, 1792, 2048, 2304, 2560, 2816, 3072, 3328, 3584, 3840, 4096, 4608, 5120, 5632, 6144, 6656, 7168, 7680, 8192]
#   [sglang]
#   [sglang]   0%|          | 0/58 [00:00<?, ?it/s]
# ...
#     Batch    8 ... 1,051.7 tok/s  (8/8 ok)
#     Batch   32 ... 2,687.7 tok/s  (32/32 ok)
#     Batch   64 ... 3,585.2 tok/s  (64/64 ok)
# 🧹 Stopping sglang on port 8000...
#
#   Saved 31 rows → results_no_radix.csv
#
# Saved 31 rows -> results_sglang_no_radix.csv
#                                   run_id                   timestamp  \
# 25                       100.00                  NaN
# 26                         0.00                  NaN
# 27                       100.00                  NaN
# 28                       100.00                  NaN
# 29                        56.25                  NaN
# 30                         0.00                  NaN
#
# [31 rows x 32 columns]

# %% [markdown]
# ## 8. Test 3 — Torch Compile
#
# Starts a fresh SGLang server with `--enable-torch-compile`. This uses
# PyTorch's `torch.compile` to JIT-compile the model, reducing Python
# overhead and fusing kernels. Expect a **longer server startup** (compilation
# happens on first few requests) but potentially higher steady-state throughput.
#
# **Note**: If torch.compile is not supported for your SGLang version or model,
# this test will report startup errors — the other tests remain unaffected.

# %%
print("=" * 60)
print("TEST 3: Torch Compile")
print("=" * 60)

config_torch_compile = SGLANG_TEST_CONFIGS[2]  # "torch_compile"
df_torch_compile = run_single_config(config_torch_compile)

df_torch_compile.to_csv("results_sglang_torch_compile.csv", index=False)
print(f"\nSaved {len(df_torch_compile)} rows -> results_sglang_torch_compile.csv")
df_torch_compile
# Out:
# ============================================================
# TEST 3: Torch Compile
# ============================================================
#
# ============================================================
# Workload: random_short — Short prompts (<100 tokens) - tests raw decode speed
# ============================================================
#
# 🚀 Starting SGLang server on port 8000:
#    python -m sglang.launch_server --model-path meta-llama/Llama-3.2-3B-Instruct --host 0.0.0.0 --port 8000 --dtype bfloat16 --mem-fraction-static 0.9 --context-length 8192 --enable-torch-compile --enable-metrics
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/launch_server.py:51: UserWarning: 'python -m sglang.launch_server' is still supported, but 'sglang serve' is the recommended entrypoint.
#   [sglang]   Example: sglang serve --model-path <model> [options]
#   [sglang]   warnings.warn(
#   [sglang] /usr/local/lib/python3.12/dist-packages/sglang/srt/entrypoints/http_server.py:172: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
#   [sglang]   from sglang.srt.utils.json_response import (
#   [sglang] [2026-04-16 15:09:08] server_args=ServerArgs(model_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_path='meta-llama/Llama-3.2-3B-Instruct', tokenizer_mode='auto', tokenizer_worker_num=1, skip_tokenizer_init=False, load_format='auto', model_loader_extra_config='{}', trust_remote_code=False, context_length=8192, is_embedding=False, enable_multimodal=None, revision=None, model_impl='auto', host='0.0.0.0', port=8000, fastapi_root_path='', grpc_mode=False, skip_server_warmup=False, warmups=None, nccl_port=None, checkpoint_engine_wait_weights_before_ready=False, ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_keyfile_password=None, enable_ssl_refresh=False, dtype='bfloat16', quantization=None, quantization_param_path=None, kv_cache_dtype='auto', enable_fp32_lm_head=False, modelopt_quant=None, modelopt_checkpoint_restore_path=None, modelopt_checkpoint_save_path=None, modelopt_export_path=None, quantize_and_serve=False, rl_quant_profile=None, mem_fraction_static=0.9, max_running_requests=None, max_queued_requests=None, max_total_tokens=None, chunked_prefill_size=8192, enable_dynamic_chunking=False, max_prefill_tokens=16384, prefill_max_requests=None, schedule_policy='fcfs', enable_priority_scheduling=False, disable_priority_preemption=False, default_priority_value=None, abort_on_priority_when_disabled=False, schedule_low_priority_values_first=False, priority_scheduling_preemption_threshold=10, schedule_conservativeness=1.0, page_size=1, swa_full_tokens_ratio=0.8, disable_hybrid_swa_memory=False, radix_eviction_policy='lru', enable_prefill_delayer=False, prefill_delayer_max_delay_passes=30, prefill_delayer_token_usage_low_watermark=None, prefill_delayer_forward_passes_buckets=None, prefill_delayer_wait_seconds_buckets=None, device='cuda', tp_size=1, pp_size=1, pp_max_micro_batch_size=None, pp_async_batch_depth=0, stream_interval=1, stream_response_default_include_usage=False, incremental_streaming_output=False, enable_streaming_session=False, random_seed=679733092, constrained_json_whitespace_pattern=None, constrained_json_disable_any_whitespace=False, watchdog_timeout=300, soft_watchdog_timeout=None, dist_timeout=None, download_dir=None, model_checksum=None, base_gpu_id=0, gpu_id_step=1, sleep_on_idle=False, use_ray=False, custom_sigquit_handler=None, log_level='info', log_level_http=None, log_requests=False, log_requests_level=2, log_requests_format='text', log_requests_target=None, uvicorn_access_log_exclude_prefixes=[], crash_dump_folder=None, show_time_cost=False, enable_metrics=True, enable_mfu_metrics=False, enable_metrics_for_all_schedulers=False, tokenizer_metrics_custom_labels_header='x-custom-labels', tokenizer_metrics_allowed_custom_labels=None, extra_metric_labels=None, bucket_time_to_first_token=None, bucket_inter_token_latency=None, bucket_e2e_request_latency=None, collect_tokens_histogram=False, prompt_tokens_buckets=None, generation_tokens_buckets=None, gc_warning_threshold_secs=0.0, decode_log_interval=40, enable_request_time_stats_logging=False, kv_events_config=None, enable_trace=False, otlp_traces_endpoint='localhost:4317', export_metrics_to_file=False, export_metrics_to_file_dir=None, api_key=None, admin_api_key=None, served_model_name='meta-llama/Llama-3.2-3B-Instruct', weight_version='default', chat_template=None, hf_chat_template_name=None, completion_template=None, file_storage_path='sglang_storage', enable_cache_report=False, reasoning_parser=None, tool_call_parser=None, tool_server=None, sampling_defaults='model', dp_size=1, load_balance_method='round_robin', attn_cp_size=1, moe_dp_size=1, dist_init_addr=None, nnodes=1, node_rank=0, json_model_override_args='{}', preferred_sampling_params=None, enable_lora=None, enable_lora_overlap_loading=None, max_lora_rank=None, lora_target_modules=None, lora_paths=None, max_loaded_loras=None, max_loras_per_batch=8, lora_eviction_policy='lru', lora_backend='csgmv', max_lora_chunk_size=16, experts_shared_outer_loras=None, attention_backend='flashi ...
#   [sglang] [2026-04-16 15:09:14] Using default HuggingFace chat template with detected content format: string
#   [sglang] [2026-04-16 15:09:30] Init torch distributed begin.
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   [sglang] [2026-04-16 15:09:30] Init torch distributed ends. elapsed=0.41 s, mem usage=0.08 GB
#   [sglang] [2026-04-16 15:09:33] Load weight begin. avail mem=78.74 GB
#   [sglang] [2026-04-16 15:09:33] Found local HF snapshot for meta-llama/Llama-3.2-3B-Instruct at /root/.cache/huggingface/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95; skipping download.
#   [sglang]
#   [sglang] Multi-thread loading shards:   0% Completed | 0/2 [00:00<?, ?it/s]
#   [sglang] Multi-thread loading shards:  50% Completed | 1/2 [00:01<00:01,  1.37s/it]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.17it/s]
#   [sglang] Multi-thread loading shards: 100% Completed | 2/2 [00:01<00:00,  1.07it/s]
#   [sglang] [2026-04-16 15:09:36] Load weight end. elapsed=2.51 s, type=LlamaForCausalLM, avail mem=72.67 GB, mem usage=6.06 GB.
#   [sglang] [2026-04-16 15:09:36] Using KV cache dtype: torch.bfloat16
#   [sglang] [2026-04-16 15:09:36] KV Cache is allocated. #tokens: 606631, K size: 32.40 GB, V size: 32.40 GB
#   [sglang] [2026-04-16 15:09:36] Memory pool end. avail mem=7.68 GB
#   [sglang] [2026-04-16 15:09:36] Capture cuda graph begin. This can take up to several minutes. avail mem=7.25 GB
#   [sglang] [2026-04-16 15:09:36] Capture cuda graph bs [1, 2, 4, 8, 12, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256]
#   [sglang]
#   [sglang]   0%|          | 0/36 [00:00<?, ?it/s]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   0%|          | 0/36 [00:00<?, ?it/s]2026-04-16 15:09:38,486 - CUTE_DSL - WARNING - [handle_import_error] - Unexpected error during package walk: cutlass.cute.experimental
#   [sglang] [2026-04-16 15:09:38] Unexpected error during package walk: cutlass.cute.experimental
#   [sglang]
#   [sglang] Capturing batches (bs=256 avail_mem=7.11 GB):   3%|▎         | 1/36 [00:02<01:37,  2.79s/it]
#   [sglang] Capturing batches (bs=248 avail_mem=6.98 GB):   3%|▎         | 1/36 [00:02<01:37,  2.79s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   3%|▎         | 1/36 [00:02<01:37,  2.79s/it]
#   [sglang] Capturing batches (bs=240 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=232 avail_mem=6.97 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):   8%|▊         | 3/36 [00:02<00:25,  1.30it/s]
#   [sglang] Capturing batches (bs=224 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=216 avail_mem=6.95 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  14%|█▍        | 5/36 [00:03<00:12,  2.45it/s]
#   [sglang] Capturing batches (bs=208 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=200 avail_mem=6.92 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  19%|█▉        | 7/36 [00:03<00:07,  3.83it/s]
#   [sglang] Capturing batches (bs=192 avail_mem=6.90 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.38it/s]
#   [sglang] Capturing batches (bs=184 avail_mem=6.89 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.38it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  25%|██▌       | 9/36 [00:03<00:05,  5.38it/s]
#   [sglang] Capturing batches (bs=176 avail_mem=6.87 GB):  31%|███       | 11/36 [00:03<00:03,  7.01it/s]
#   [sglang] Capturing batches (bs=168 avail_mem=6.86 GB):  31%|███       | 11/36 [00:03<00:03,  7.01it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  31%|███       | 11/36 [00:03<00:03,  7.01it/s]
#   [sglang] Capturing batches (bs=160 avail_mem=6.84 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.64it/s]
#   [sglang] Capturing batches (bs=152 avail_mem=6.83 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.64it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  36%|███▌      | 13/36 [00:03<00:02,  8.64it/s]
#   [sglang] Capturing batches (bs=144 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.17it/s]
#   [sglang] Capturing batches (bs=136 avail_mem=6.81 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.17it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  42%|████▏     | 15/36 [00:03<00:02, 10.17it/s]
#   [sglang] Capturing batches (bs=128 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.52it/s]
#   [sglang] Capturing batches (bs=120 avail_mem=6.78 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.52it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  47%|████▋     | 17/36 [00:03<00:01, 11.52it/s]
#   [sglang] Capturing batches (bs=112 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.72it/s]
#   [sglang] Capturing batches (bs=104 avail_mem=6.75 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.72it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  53%|█████▎    | 19/36 [00:03<00:01, 12.72it/s]
#   [sglang] Capturing batches (bs=96 avail_mem=6.73 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13.68it/s]
#   [sglang] Capturing batches (bs=88 avail_mem=6.72 GB):  58%|█████▊    | 21/36 [00:04<00:01, 13
5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang]   triton_mm_198 0.0389 ms 60.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang] SingleProcess AUTOTUNE benchmarking takes 0.3425 seconds and 0.8809 seconds precompiling for 18 choices
#   [sglang] Autotune Choices Stats:
#   [sglang] {"num_choices": 18, "num_triton_choices": 17, "best_kernel": "triton_mm_208", "best_kernel_desc": "ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2", "best_time": 0.0798719972372055, "best_triton_pos": 0}
#   [sglang] AUTOTUNE mm(16x3072, 3072x16384)
#   [sglang] strides: [3072, 1], [1, 3072]
#   [sglang] dtypes: torch.bfloat16, torch.bfloat16
#   [sglang]   triton_mm_208 0.0799 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   [sglang]   triton_mm_215 0.0799 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang]   triton_mm_216 0.0799 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   [sglang]   triton_mm_205 0.0819 ms 97.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=2
#   [sglang]   triton_mm_211 0.0819 ms 97.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang]   triton_mm_212 0.0829 ms 96.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang]   triton_mm_220 0.0829 ms 96.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   [sglang]   mm 0.0963 ms 83.0%
#   [sglang]   triton_mm_218 0.0973 ms 82.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   [sglang]   triton_mm_206 0.0993 ms 80.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang] SingleProcess AUTOTUNE benchmarking takes 0.4368 seconds and 0.9889 seconds precompiling for 18 choices
#   [sglang] Autotune Choices Stats:
#   [sglang] {"num_choices": 18, "num_triton_choices": 17, "best_kernel": "triton_mm_225", "best_kernel_desc": "ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2", "best_time": 0.05119999870657921, "best_triton_pos": 0}
#   [sglang] AUTOTUNE mm(16x8192, 8192x3072)
#   [sglang] strides: [8192, 1], [1, 8192]
#   [sglang] dtypes: torch.bfloat16, torch.bfloat16
#   [sglang]   triton_mm_225 0.0512 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   [sglang]   triton_mm_229 0.0512 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang]   triton_mm_233 0.0563 ms 90.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   [sglang]   mm 0.0584 ms 87.7%
#   [sglang]   triton_mm_237 0.0635 ms 80.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   [sglang]   triton_mm_224 0.0758 ms 67.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   [sglang]   triton_mm_222 0.0768 ms 66.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=2
#   [sglang]   triton_mm_228 0.0788 ms 64.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang]   triton_mm_223 0.0809 ms 63.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang]   triton_mm_232 0.0850 ms 60.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang] SingleProcess AUTOTUNE benchmarking takes 0.4370 seconds and 0.0003 seconds precompiling for 18 choices
#   [sglang] Autotune Choices Stats:
#   [sglang] {"num_choices": 18, "num_triton_choices": 17, "best_kernel": "triton_mm_250", "best_kernel_desc": "ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4", "best_time": 0.4546560049057007, "best_triton_pos": 0}
#   [sglang] AUTOTUNE mm(16x3072, 3072x128256)
#   [sglang] strides: [3072, 1], [1, 3072]
#   [sglang] dtypes: torch.bfloat16, torch.bfloat16
#   [sglang]   triton_mm_250 0.4547 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   [sglang]   triton_mm_246 0.4608 ms 98.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   [sglang]   triton_mm_242 0.4700 ms 96.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   [sglang]   mm 0.4762 ms 95.5%
#   [sglang]   triton_mm_239 0.4772 ms 95.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=2
#   [sglang]   triton_mm_254 0.4772 ms 95.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   [sglang]   triton_mm_249 0.4803 ms 94.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   [sglang]   triton_mm_245 0.4864 ms 93.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# ...
#                                        run_id                   timestamp  \
# 0     torch_compile_random_short_1_1776352415  2026-04-16T15:13:35.461435
# 1     torch_compile_random_short_8_1776352416  2026-04-16T15:13:36.221695
# 2    torch_compile_random_short_32_1776352417  2026-04-16T15:13:37.111608
# 3    torch_compile_random_short_64_1776352418  2026-04-16T15:13:38.596660
# 4    torch_compile_random_medium_1_1776352558  2026-04-16T15:15:58.756083
# 5    torch_compile_random_medium_8_1776352559  2026-04-16T15:15:59.583497
# 6   torch_compile_random_medium_32_1776352560  2026-04-16T15:16:00.459897
# 7   torch_compile_random_medium_64_1776352561  2026-04-16T15:16:01.908786
# 8     torch_compile_long_context_1_1776352701  2026-04-16T15:18:21.015926
# 9     torch_compile_long_context_8_1776352701  2026-04-16T15:18:21.955062
# 10   torch_compile_long_context_32_1776352703  2026-04-16T15:18:23.217851
# 11   torch_compile_mixed_context_1_1776352844  2026-04-16T15:20:44.869524
# 12   torch_compile_mixed_context_8_1776352848  2026-04-16T15:20:48.524965
# 13  torch_compile_mixed_context_32_1776352855  2026-04-16T15:20:55.190533
# 14   torch_compile_shared_prefix_1_1776352993  2026-04-16T15:23:13.893188
# 15   torch_compile_shared_prefix_8_1776352994  2026-04-16T15:23:14.491438
# 16  torch_compile_shared_prefix_32_1776352995  2026-04-16T15:23:15.264523
# 17      torch_compile_repetitive_1_1776353133  2026-04-16T15:25:33.878604
# 18      torch_compile_repetitive_8_1776353134  2026-04-16T15:25:34.632768
# 19            torch_compile_code_1_1776353277  2026-04-16T15:27:57.014508
# 20            torch_compile_code_8_1776353277  2026-04-16T15:27:57.762151
# 21           torch_compile_code_32_1776353278  2026-04-16T15:27:58.667325
# 22           torch_compile_code_64_1776353280  2026-04-16T15:28:00.133056
# 23        torch_compile_sharegpt_1_1776353417  2026-04-16T15:30:17.316097
# 24        torch_compile_sharegpt_8_1776353420  2026-04-16T15:30:20.334121
# 25       torch_compile_sharegpt_32_1776353424  2026-04-16T15:30:24.100201
# 26       torch_compile_sharegpt_64_1776353429  2026-04-16T15:30:29.720458
# 27          torch_compile_sonnet_1_1776353566  2026-04-16T15:32:46.857904
# 28          torch_compile_sonnet_8_1776353567  2026-04-16T15:32:47.890021
# 29         torch_compile_sonnet_32_1776353569  2026-04-16T15:32:49.470567
# 30         torch_compile_sonnet_64_1776353571  2026-04-16T15:32:51.854819
#
#       config_name  workload_name  batch_size  throughput_output_tok_s  \
# 0   torch_compile   random_short           1                     4.24
# 1   torch_compile   random_short           8                  1110.37
# 2   torch_compile   random_short          32                  4223.84
# 3   torch_compile   random_short          64                  5139.79
# 4   torch_compile  random_medium           1                   166.53
# 5   torch_compile  random_medium           8                   589.51
# 6   torch_compile  random_medium          32                  2209.20
# 7   torch_compile  random_medium          64                  2835.21
# 8   torch_compile   long_context           1                   148.89
# 9   torch_compile   long_context           8                   682.42
# 10  torch_compile   long_context          32                  2143.75
# 11  torch_compile  mixed_context           1                   159.26
# 12  torch_compile  mixed_context           8                   438.37
# 13  torch_compile  mixed_context          32                  1140.14
# 14  torch_compile  shared_prefix           1                   163.85
# 15  torch_compile  shared_prefix           8                  1197.29
# 16  torch_compile  shared_prefix          32                  3701.94
# 17  torch_compile     repetitive           1                   165.96
# 18  torch_compile     repetitive           8                  1066.76
# 19  torch_compile           code           1                   176.22
# 20  torch_compile           code           8                  1385.92
# 21  torch_compile           code          32                  4579.24
# 22  torch_compile           code          64                  5650.16
# 23  torch_compile       sharegpt           1                   176.86
# 24  torch_compile       sharegpt           8                  1080.72
# 25  torch_compile       sharegpt          32                  3256.39
# 26  torch_compile       sharegpt          64                  4726.79
# 27  torch_compile         sonnet           1                   172.00
# 28  torch_compile         sonnet           8                  1173.93
# 29  torch_compile         sonnet          32                  3064.69
# 30  torch_compile         sonnet          64                  4061.45
#
#     throughput_total_tok_s  ttft_p50_ms  ttft_p95_ms  ttft_p99_ms  ...  \
# 0                     4.46      8782.34      8782.34      8782.34  ...
# 1                  1131.49        67.47        70.18        70.41  ...
# 2                  4296.04       128.87       137.90       138.39  ...
# 3                  5226.23       615.98       801.91       803.57  ...
# 14                 0.0                                99.37
# 15                 0.0                                91.37
# 16                 0.0                                90.10
# 17                 0.0                                99.64
# 18                 0.0                                79.11
# 19                 0.0                                99.74
# 20                 0.0                                99.05
# 21                 0.0                                97.75
# 22                 0.0                                80.30
# 23                 0.0                                99.60
# 24                 0.0                                80.38
# 25                 0.0                                76.68
# 26                 0.0                                80.79
# 27                 0.0                                99.52
# 28                 0.0                                98.60
# 29                 0.0                                97.18
# 30                 0.0                                91.89
#
#     goodput_throughput_per_watt  goodput_sla_ttft_target_ms  \
# 0                           0.0                       500.0
# 1                           0.0                       500.0
# 2                           0.0                       500.0
# 3                           0.0                       500.0
# 4                           0.0                       500.0
# 5                           0.0                       500.0
# 6                           0.0                       500.0
# 7                           0.0                       500.0
# 8                           0.0                       500.0
# 9                           0.0                       500.0
# 10                          0.0                       500.0
# 11                          0.0                       500.0
# 12                          0.0                       500.0
# 13                          0.0                       500.0
# 14                          0.0                       500.0
# 15                          0.0                       500.0
# 16                          0.0                       500.0
# 17                          0.0                       500.0
# 18                          0.0                       500.0
# 19                          0.0                       500.0
# 20                          0.0                       500.0
# 21                          0.0                       500.0
# 22                          0.0                       500.0
# 23                          0.0                       500.0
# 24                          0.0                       500.0
# 25                          0.0                       500.0
# 26                          0.0                       500.0
# 27                          0.0                       500.0
# 28                          0.0                       500.0
# 29                          0.0                       500.0
# 30                          0.0                       500.0
#
#     goodput_sla_compliance_rate  speedup_vs_baseline  error_message
# 0                           0.0                  NaN
# 1                         100.0                  NaN
# 2                         100.0                  NaN
# 3                           0.0                  NaN
# 4                         100.0                  NaN
# 5                         100.0                  NaN
# 6                         100.0                  NaN
# 7                           0.0                  NaN
# 8                         100.0                  NaN
# 9                         100.0                  NaN
# 10                        100.0                  NaN
# 11                        100.0                  NaN
# 12                         75.0                  NaN
# 13                          0.0                  NaN
# 14                        100.0                  NaN
# 15                        100.0                  NaN
# 16                        100.0                  NaN
# 17                        100.0                  NaN
# 18                        100.0                  NaN
# 19                        100.0                  NaN
# 20                        100.0                  NaN
# 21                        100.0                  NaN
# 22                          0.0                  NaN
# 23                        100.0                  NaN
# 24                        100.0                  NaN
# 25                        100.0                  NaN
# 26                          0.0                  NaN
# 27                        100.0                  NaN
# 28                        100.0                  NaN
# 29                        100.0                  NaN
# 30                          0.0                  NaN
#
# [31 rows x 32 columns]

# %% [markdown]
# ---
# ## 9. Combine Results & Compute Speedups
#
# Merges the three per-config DataFrames, computes speedup-vs-baseline for
# every row, and saves the combined CSV.

# %%
import time, pandas as pd, numpy as np

# Combine
df_all = pd.concat([df_baseline, df_no_radix, df_torch_compile], ignore_index=True)

# Build baseline throughput lookup
bl = df_baseline.set_index(["workload_name", "batch_size"])["throughput_output_tok_s"]

def _speedup(row):
    key = (row["workload_name"], row["batch_size"])
    base = bl.get(key, None)
    if base and base > 0:
        return round(row["throughput_output_tok_s"] / base, 3)
    return np.nan

df_all["speedup_vs_baseline"] = df_all.apply(_speedup, axis=1)

ts = time.strftime("%Y%m%d_%H%M%S")
combined_csv = f"results_sglang_combined_{ts}.csv"
df_all.to_csv(combined_csv, index=False)
print(f"Combined {len(df_all)} rows -> {combined_csv}")
print(f"Configs : {sorted(df_all['config_name'].unique())}")
print(f"Workloads: {sorted(df_all['workload_name'].unique())}")
df_all[["config_name", "workload_name", "batch_size",
        "throughput_output_tok_s", "ttft_p50_ms", "itl_p50_ms",
        "speedup_vs_baseline"]]
# Out:
# Combined 93 rows -> results_sglang_combined_20260416_153257.csv
# Configs : ['baseline', 'no_radix', 'torch_compile']
# Workloads: ['code', 'long_context', 'mixed_context', 'random_medium', 'random_short', 'repetitive', 'shared_prefix', 'sharegpt', 'sonnet']
#       config_name  workload_name  batch_size  throughput_output_tok_s  \
# 0        baseline   random_short           1                   161.98
# 1        baseline   random_short           8                   875.16
# 2        baseline   random_short          32                  4056.60
# 3        baseline   random_short          64                  5036.08
# 4        baseline  random_medium           1                   167.36
# ..            ...            ...         ...                      ...
# 88  torch_compile       sharegpt          64                  4726.79
# 89  torch_compile         sonnet           1                   172.00
# 90  torch_compile         sonnet           8                  1173.93
# 91  torch_compile         sonnet          32                  3064.69
# 92  torch_compile         sonnet          64                  4061.45
#
#     ttft_p50_ms  itl_p50_ms  speedup_vs_baseline
# 0         19.27        5.38                1.000
# 1        173.23        6.14                1.000
# 2         76.22        6.29                1.000
# 3        622.99        3.48                1.000
# 4         19.67        5.60                1.000
# ..          ...         ...                  ...
# 88       753.21        9.29                1.020
# 89        45.28        5.08                1.029
# 90       159.53        5.72                1.107
# 91       333.95        7.15                1.064
# 92       778.83        9.72                1.033
#
# [93 rows x 7 columns]

# %% [markdown]
# ---
# # Comparison & Visualization
#
# The cells below graph every key metric across the three configurations
# and five workloads.  All plots pull from `df_all`.

# %% [markdown]
# ## 10. Throughput Comparison
#
# Output tokens/second for each workload, broken down by batch size and
# configuration. Higher is better.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", font_scale=1.05)
PALETTE = sns.color_palette("Set2", n_colors=df_all["config_name"].nunique())
CONFIG_ORDER = sorted(df_all["config_name"].unique())

workloads = sorted(df_all["workload_name"].unique())
n_wl = len(workloads)
ncols = min(3, n_wl)
nrows = (n_wl + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 5 * nrows),
                         squeeze=False)

for idx, wl in enumerate(workloads):
    ax = axes[idx // ncols][idx % ncols]
    sub = df_all[df_all["workload_name"] == wl].copy()
    pivot = sub.pivot_table(
        index="batch_size", columns="config_name",
        values="throughput_output_tok_s", aggfunc="first",
    ).reindex(columns=CONFIG_ORDER)
    pivot.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)], edgecolor="black",
                   linewidth=0.4)
    ax.set_title(wl, fontweight="bold")
    ax.set_ylabel("Output tok/s")
    ax.set_xlabel("Batch Size")
    ax.tick_params(axis="x", rotation=0)
    ax.legend(title="Config", fontsize=8, title_fontsize=9)

# hide unused subplots
for idx in range(n_wl, nrows * ncols):
    axes[idx // ncols][idx % ncols].set_visible(False)

fig.suptitle("SGLang Throughput Comparison  (output tok/s, higher is better)",
             fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("plot_sglang_throughput.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 11. Time-to-First-Token (TTFT) Comparison
#
# TTFT at p50, p95, and p99 for each workload.  Lower is better.

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 5 * nrows),
                         squeeze=False)

for idx, wl in enumerate(workloads):
    ax = axes[idx // ncols][idx % ncols]
    sub = df_all[df_all["workload_name"] == wl].copy()

    # p50 bars
    pivot50 = sub.pivot_table(
        index="batch_size", columns="config_name",
        values="ttft_p50_ms", aggfunc="first",
    ).reindex(columns=CONFIG_ORDER)
    bars = pivot50.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                            edgecolor="black", linewidth=0.4)

    # overlay p95 as error caps
    pivot95 = sub.pivot_table(
        index="batch_size", columns="config_name",
        values="ttft_p95_ms", aggfunc="first",
    ).reindex(columns=CONFIG_ORDER)
    for j, cfg in enumerate(CONFIG_ORDER):
        if cfg in pivot50.columns and cfg in pivot95.columns:
            x_positions = [p.get_x() + p.get_width() / 2
                           for p in bars.patches[j::len(CONFIG_ORDER)]]
            y_lo = pivot50[cfg].values
            y_hi = pivot95[cfg].values
            yerr = np.clip(y_hi - y_lo, 0, None)
            ax.errorbar(x_positions[:len(y_lo)], y_lo, yerr=yerr, fmt="none",
                        ecolor="gray", capsize=3, capthick=0.8, linewidth=0.8)

    ax.set_title(wl, fontweight="bold")
    ax.set_ylabel("TTFT (ms)")
    ax.set_xlabel("Batch Size")
    ax.tick_params(axis="x", rotation=0)
    ax.legend(title="Config", fontsize=8, title_fontsize=9)

for idx in range(n_wl, nrows * ncols):
    axes[idx // ncols][idx % ncols].set_visible(False)

fig.suptitle("SGLang Time to First Token  (p50 bars + p95 caps, lower is better)",
             fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("plot_sglang_ttft.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 12. Inter-Token Latency (ITL) Comparison
#
# ITL p50 with p95 error caps. Lower is better for streaming applications.

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 5 * nrows),
                         squeeze=False)

for idx, wl in enumerate(workloads):
    ax = axes[idx // ncols][idx % ncols]
    sub = df_all[df_all["workload_name"] == wl].copy()

    pivot50 = sub.pivot_table(
        index="batch_size", columns="config_name",
        values="itl_p50_ms", aggfunc="first",
    ).reindex(columns=CONFIG_ORDER)
    bars = pivot50.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                            edgecolor="black", linewidth=0.4)

    pivot95 = sub.pivot_table(
        index="batch_size", columns="config_name",
        values="itl_p95_ms", aggfunc="first",
    ).reindex(columns=CONFIG_ORDER)
    for j, cfg in enumerate(CONFIG_ORDER):
        if cfg in pivot50.columns and cfg in pivot95.columns:
            x_positions = [p.get_x() + p.get_width() / 2
                           for p in bars.patches[j::len(CONFIG_ORDER)]]
            y_lo = pivot50[cfg].values
            y_hi = pivot95[cfg].values
            yerr = np.clip(y_hi - y_lo, 0, None)
            ax.errorbar(x_positions[:len(y_lo)], y_lo, yerr=yerr, fmt="none",
                        ecolor="gray", capsize=3, capthick=0.8, linewidth=0.8)

    ax.set_title(wl, fontweight="bold")
    ax.set_ylabel("ITL (ms)")
    ax.set_xlabel("Batch Size")
    ax.tick_params(axis="x", rotation=0)
    ax.legend(title="Config", fontsize=8, title_fontsize=9)

for idx in range(n_wl, nrows * ncols):
    axes[idx // ncols][idx % ncols].set_visible(False)

fig.suptitle("SGLang Inter-Token Latency  (p50 bars + p95 caps, lower is better)",
             fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("plot_sglang_itl.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 13. Speedup vs Baseline
#
# Heatmaps showing how much faster (or slower) each config is relative to
# the baseline (RadixAttention ON). Values > 1.0 mean the config is faster.

# %%
spec_configs = [c for c in CONFIG_ORDER if c != "baseline"]
n_spec = len(spec_configs)

if n_spec > 0:
    fig, axes = plt.subplots(1, n_spec, figsize=(7 * n_spec, 5), squeeze=False)

    for i, cfg in enumerate(spec_configs):
        ax = axes[0][i]
        sub = df_all[df_all["config_name"] == cfg].copy()
        pivot = sub.pivot_table(
            index="batch_size", columns="workload_name",
            values="speedup_vs_baseline", aggfunc="first",
        )
        # Sort columns for consistency
        pivot = pivot.reindex(columns=sorted(pivot.columns))

        sns.heatmap(
            pivot, annot=True, fmt=".2f", cmap="RdYlGn", center=1.0,
            linewidths=0.5, ax=ax, vmin=0.5, vmax=2.0,
            cbar_kws={"label": "Speedup"},
        )
        ax.set_title(f"{cfg}", fontweight="bold")
        ax.set_ylabel("Batch Size")
        ax.set_xlabel("Workload")

    fig.suptitle("Speedup vs Baseline  (green > 1 = faster)",
                 fontsize=15, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.savefig("plot_sglang_speedup_heatmap.png", dpi=150, bbox_inches="tight")
    plt.show()
else:
    print("No non-baseline configs to compare.")

# %% [markdown]
# ## 14. Latency vs Throughput Tradeoff
#
# Scatter plot of TTFT (latency) against throughput. Ideal configs appear
# in the **bottom-right** (high throughput, low latency).

# %%
fig, ax = plt.subplots(figsize=(10, 7))

markers = ["o", "s", "D", "^", "v"]
wl_markers = {wl: markers[i % len(markers)] for i, wl in enumerate(workloads)}
cfg_colors = {c: PALETTE[i] for i, c in enumerate(CONFIG_ORDER)}

for _, row in df_all.iterrows():
    tp = row["throughput_output_tok_s"]
    ttft = row["ttft_p50_ms"]
    if pd.isna(tp) or pd.isna(ttft) or tp <= 0:
        continue
    ax.scatter(
        tp, ttft,
        c=[cfg_colors[row["config_name"]]],
        marker=wl_markers[row["workload_name"]],
        s=30 + row["batch_size"] * 1.5,
        alpha=0.75, edgecolors="black", linewidth=0.4,
    )

# Legends
from matplotlib.lines import Line2D
cfg_handles = [
    Line2D([0], [0], marker="o", color="w", markerfacecolor=cfg_colors[c],
           markersize=8, markeredgecolor="black", linewidth=0.4, label=c)
    for c in CONFIG_ORDER
]
wl_handles = [
    Line2D([0], [0], marker=wl_markers[w], color="w", markerfacecolor="gray",
           markersize=8, markeredgecolor="black", linewidth=0.4, label=w)
    for w in workloads
]
legend1 = ax.legend(handles=cfg_handles, title="Config", loc="upper left",
                     fontsize=8, title_fontsize=9)
ax.add_artist(legend1)
ax.legend(handles=wl_handles, title="Workload", loc="upper right",
          fontsize=8, title_fontsize=9)

ax.set_xlabel("Output Throughput (tok/s)", fontsize=12)
ax.set_ylabel("TTFT p50 (ms)  [lower is better]", fontsize=12)
ax.set_title("SGLang Latency vs Throughput Tradeoff  (bottom-right is ideal)",
             fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig("plot_sglang_latency_vs_throughput.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 15. Goodput & Reliability
#
# Compares raw throughput vs goodput (successful tokens only) and shows
# success rates across configurations.

# %%
goodput_col = "goodput_goodput_tok_s"
success_col = "goodput_success_rate"
sla_col = "goodput_sla_compliance_rate"

has_goodput = goodput_col in df_all.columns and df_all[goodput_col].notna().any()
has_success = success_col in df_all.columns and df_all[success_col].notna().any()

if has_goodput or has_success:
    n_panels = sum([has_goodput, has_success, sla_col in df_all.columns])
    fig, axes = plt.subplots(1, n_panels, figsize=(6 * n_panels, 5), squeeze=False)
    panel = 0

    # -- Raw throughput vs Goodput --
    if has_goodput:
        ax = axes[0][panel]
        panel += 1
        compare = df_all.groupby("config_name").agg(
            raw_tp=("throughput_output_tok_s", "mean"),
            goodput=(goodput_col, "mean"),
        )
        compare.plot.bar(ax=ax, color=[PALETTE[0], PALETTE[1]],
                         edgecolor="black", linewidth=0.4)
        ax.set_title("Avg Raw Throughput vs Goodput", fontweight="bold")
        ax.set_ylabel("tok/s")
        ax.tick_params(axis="x", rotation=15)

    # -- Success rate by config + workload --
    if has_success:
        ax = axes[0][panel]
        panel += 1
        pivot_sr = df_all.pivot_table(
            index="workload_name", columns="config_name",
            values=success_col, aggfunc="mean",
        ).reindex(columns=CONFIG_ORDER)
        pivot_sr.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                          edgecolor="black", linewidth=0.4)
        ax.set_title("Success Rate by Workload", fontweight="bold")
        ax.set_ylabel("Success Rate (%)")
        ax.set_ylim(0, 105)
        ax.axhline(100, color="green", linestyle="--", alpha=0.4)
        ax.tick_params(axis="x", rotation=25)

    # -- SLA compliance --
    if sla_col in df_all.columns and df_all[sla_col].notna().any():
        ax = axes[0][panel]
        panel += 1
        pivot_sla = df_all.pivot_table(
            index="workload_name", columns="config_name",
            values=sla_col, aggfunc="mean",
        ).reindex(columns=CONFIG_ORDER)
        pivot_sla.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                           edgecolor="black", linewidth=0.4)
        ax.set_title("SLA Compliance (TTFT < 500 ms)", fontweight="bold")
        ax.set_ylabel("Compliance Rate (%)")
        ax.set_ylim(0, 105)
        ax.axhline(100, color="green", linestyle="--", alpha=0.4)
        ax.tick_params(axis="x", rotation=25)

    fig.suptitle("SGLang Goodput & Reliability", fontsize=15, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.savefig("plot_sglang_goodput.png", dpi=150, bbox_inches="tight")
    plt.show()
else:
    print("No goodput/success-rate data available.")

# %% [markdown]
# ## 16. KV Cache Analysis
#
# KV cache utilization and prefix-cache hit rates (when available).
# RadixAttention's benefit should be visible as higher prefix cache hit rates
# in the baseline config vs no_radix.

# %%
kv_util_col = "kv_cache_utilization_pct"
prefix_col = "kv_prefix_cache_hit_rate"

has_kv = kv_util_col in df_all.columns and df_all[kv_util_col].notna().any()
has_prefix = prefix_col in df_all.columns and df_all[prefix_col].notna().any()

if has_kv or has_prefix:
    n_panels = sum([has_kv, has_prefix])
    fig, axes = plt.subplots(1, n_panels, figsize=(7 * n_panels, 5), squeeze=False)
    panel = 0

    if has_kv:
        ax = axes[0][panel]
        panel += 1
        pivot_kv = df_all.pivot_table(
            index="batch_size", columns="config_name",
            values=kv_util_col, aggfunc="mean",
        ).reindex(columns=CONFIG_ORDER)
        pivot_kv.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                          edgecolor="black", linewidth=0.4)
        ax.set_title("KV Cache Utilization by Batch Size", fontweight="bold")
        ax.set_ylabel("Utilization (%)")
        ax.set_xlabel("Batch Size")
        ax.tick_params(axis="x", rotation=0)

    if has_prefix:
        ax = axes[0][panel]
        panel += 1
        pivot_prefix = df_all.pivot_table(
            index="workload_name", columns="config_name",
            values=prefix_col, aggfunc="mean",
        ).reindex(columns=CONFIG_ORDER)
        pivot_prefix.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                              edgecolor="black", linewidth=0.4)
        ax.set_title("Prefix Cache Hit Rate by Workload", fontweight="bold")
        ax.set_ylabel("Hit Rate (%)")
        ax.set_xlabel("Workload")
        ax.tick_params(axis="x", rotation=25)

    fig.suptitle("SGLang KV Cache Analysis", fontsize=15, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.savefig("plot_sglang_kv_cache.png", dpi=150, bbox_inches="tight")
    plt.show()
else:
    print("No KV cache metrics available.")
# Out:
# No KV cache metrics available.

# %% [markdown]
# ## 17. Request Latency Distribution
#
# Mean request latency across workloads, grouped by config and batch size.

# %%
lat_col = "request_latency_mean_ms"

if lat_col in df_all.columns and df_all[lat_col].notna().any():
    fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 5 * nrows),
                             squeeze=False)
    for idx, wl in enumerate(workloads):
        ax = axes[idx // ncols][idx % ncols]
        sub = df_all[df_all["workload_name"] == wl]
        pivot = sub.pivot_table(
            index="batch_size", columns="config_name",
            values=lat_col, aggfunc="first",
        ).reindex(columns=CONFIG_ORDER)
        pivot.plot.bar(ax=ax, color=PALETTE[:len(CONFIG_ORDER)],
                       edgecolor="black", linewidth=0.4)
        ax.set_title(wl, fontweight="bold")
        ax.set_ylabel("Mean Request Latency (ms)")
        ax.set_xlabel("Batch Size")
        ax.tick_params(axis="x", rotation=0)
        ax.legend(title="Config", fontsize=8, title_fontsize=9)

    for idx in range(n_wl, nrows * ncols):
        axes[idx // ncols][idx % ncols].set_visible(False)

    fig.suptitle("SGLang Mean Request Latency  (lower is better)",
                 fontsize=15, fontweight="bold", y=1.01)
    plt.tight_layout()
    plt.savefig("plot_sglang_request_latency.png", dpi=150, bbox_inches="tight")
    plt.show()
else:
    print("No request latency data available.")
# Out:
# No request latency data available.

# %% [markdown]
# ## 18. Scaling Efficiency
#
# Line plots showing how throughput scales with batch size for each config.
# Ideal scaling would be linear.

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 5 * nrows),
                         squeeze=False)

for idx, wl in enumerate(workloads):
    ax = axes[idx // ncols][idx % ncols]
    sub = df_all[df_all["workload_name"] == wl]

    for i, cfg in enumerate(CONFIG_ORDER):
        cfg_sub = sub[sub["config_name"] == cfg].sort_values("batch_size")
        if cfg_sub.empty:
            continue
        ax.plot(
            cfg_sub["batch_size"], cfg_sub["throughput_output_tok_s"],
            marker="o", label=cfg, color=PALETTE[i], linewidth=2,
            markersize=6,
        )

    ax.set_title(wl, fontweight="bold")
    ax.set_ylabel("Output tok/s")
    ax.set_xlabel("Batch Size")
    ax.set_xscale("log", base=2)
    ax.legend(title="Config", fontsize=8, title_fontsize=9)
    ax.grid(True, alpha=0.3)

for idx in range(n_wl, nrows * ncols):
    axes[idx // ncols][idx % ncols].set_visible(False)

fig.suptitle("SGLang Throughput Scaling with Batch Size",
             fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("plot_sglang_scaling.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 19. Comprehensive Summary
#
# Best configuration per workload (by throughput and by TTFT), plus an
# overall metrics comparison table.

# %%
print("=" * 70)
print("BEST CONFIG PER WORKLOAD  (by output throughput)")
print("=" * 70)

for wl in workloads:
    sub = df_all[df_all["workload_name"] == wl]
    if sub.empty:
        continue
    best = sub.loc[sub["throughput_output_tok_s"].idxmax()]
    print(f"  {wl:>20s}:  {best['config_name']} "
          f"(batch={int(best['batch_size'])})  "
          f"{best['throughput_output_tok_s']:.1f} tok/s")

print()
print("=" * 70)
print("BEST CONFIG PER WORKLOAD  (by lowest TTFT p50)")
print("=" * 70)

for wl in workloads:
    sub = df_all[df_all["workload_name"] == wl].dropna(subset=["ttft_p50_ms"])
    if sub.empty:
        continue
    best = sub.loc[sub["ttft_p50_ms"].idxmin()]
    print(f"  {wl:>20s}:  {best['config_name']} "
          f"(batch={int(best['batch_size'])})  "
          f"{best['ttft_p50_ms']:.1f} ms")

print()
print("=" * 70)
print("OVERALL METRICS BY CONFIG  (averaged across all workloads & batches)")
print("=" * 70)

summary_metrics = ["throughput_output_tok_s", "ttft_p50_ms", "itl_p50_ms",
                   "request_latency_mean_ms", "speedup_vs_baseline"]
available = [m for m in summary_metrics if m in df_all.columns]

summary = df_all.groupby("config_name")[available].mean().round(2)
print(summary.to_string())

# Per-workload throughput pivot
print()
print("=" * 70)
print("THROUGHPUT PIVOT  (output tok/s, rows=workload+batch, cols=config)")
print("=" * 70)
tp_pivot = df_all.pivot_table(
    index=["workload_name", "batch_size"], columns="config_name",
    values="throughput_output_tok_s", aggfunc="first",
).reindex(columns=CONFIG_ORDER)
print(tp_pivot.to_string())
# Out:
# ======================================================================
# BEST CONFIG PER WORKLOAD  (by output throughput)
# ======================================================================
#                   code:  torch_compile (batch=64)  5650.2 tok/s
#           long_context:  torch_compile (batch=32)  2143.8 tok/s
#          mixed_context:  torch_compile (batch=32)  1140.1 tok/s
#          random_medium:  torch_compile (batch=64)  2835.2 tok/s
#           random_short:  torch_compile (batch=64)  5139.8 tok/s
#             repetitive:  torch_compile (batch=8)  1066.8 tok/s
#          shared_prefix:  torch_compile (batch=32)  3701.9 tok/s
#               sharegpt:  torch_compile (batch=64)  4726.8 tok/s
#                 sonnet:  torch_compile (batch=64)  4061.4 tok/s
#
# ======================================================================
# BEST CONFIG PER WORKLOAD  (by lowest TTFT p50)
# ======================================================================
#                   code:  baseline (batch=1)  23.2 ms
#           long_context:  baseline (batch=1)  34.7 ms
#          mixed_context:  baseline (batch=1)  228.1 ms
#          random_medium:  baseline (batch=1)  19.7 ms
#           random_short:  no_radix (batch=1)  18.0 ms
#             repetitive:  baseline (batch=1)  20.0 ms
#          shared_prefix:  baseline (batch=1)  27.3 ms
#               sharegpt:  baseline (batch=1)  30.9 ms
#                 sonnet:  baseline (batch=1)  32.1 ms
#
# ======================================================================
# OVERALL METRICS BY CONFIG  (averaged across all workloads & batches)
# ======================================================================
#                throughput_output_tok_s  ttft_p50_ms  itl_p50_ms  speedup_vs_baseline
# config_name
# baseline                       1757.79       237.52        6.19                 1.00
# no_radix                       1692.00       297.01        6.22                 0.98
# torch_compile                  1831.99       544.91        5.66                 1.02
#
# ======================================================================
# THROUGHPUT PIVOT  (output tok/s, rows=workload+batch, cols=config)
# ======================================================================
# config_name               baseline  no_radix  torch_compile
# workload_name batch_size
# code          1             177.60    177.49         176.22
#               8            1272.28   1274.27        1385.92
#               32           4527.77   4481.44        4579.24
#               64           5635.27   5513.56        5650.16
# long_context  1             142.11    141.88         148.89
#               8             660.94    647.88         682.42
#               32           1996.15   1753.57        2143.75
# mixed_context 1             149.15    148.83         159.26
#               8             424.91    420.29         438.37
#               32           1068.06   1025.57        1140.14
# random_medium 1             167.36    171.04         166.53
#               8             583.29    583.29         589.51
#               32           1891.74   1869.77        2209.20
#               64           2728.30   2802.26        2835.21
# random_short  1             161.98    174.40           4.24
#               8             875.16    999.53        1110.37
#               32           4056.60   4035.57        4223.84
#               64           5036.08   5066.73        5139.79
# repetitive    1             171.09    171.72         165.96
#               8             980.86    984.63        1066.76
# shared_prefix 1             168.00    168.12         163.85
#               8            1095.15   1007.61        1197.29
#               32           3567.65   2747.95        3701.94
# sharegpt      1             168.42    164.80         176.86
#               8             962.98    939.28        1080.72
#               32           3147.86   2961.57        3256.39
#               64           4635.53   4527.74        4726.79
# sonnet        1             167.14    166.65         172.00
#               8            1060.49   1051.66        1173.93
#               32           2879.77   2687.72        3064.69
#               64           3931.79   3585.24        4061.45

# %% [markdown]
# ---
# ## 20. Export All Results
#
# Downloads the per-config CSVs, combined CSV, and all plot PNGs.

# %%
import glob
from google.colab import files

export_files = [
    "results_sglang_baseline.csv",
    "results_sglang_no_radix.csv",
    "results_sglang_torch_compile.csv",
]
# Pick up the combined CSV (timestamped)
export_files += sorted(glob.glob("results_sglang_combined_*.csv"))[-1:]
# Pick up all SGLang plots
export_files += sorted(glob.glob("plot_sglang_*.png"))

print("Downloading:")
for f in export_files:
    if os.path.exists(f):
        print(f"  {f}")
        files.download(f)
    else:
        print(f"  {f}  (not found, skipping)")
# Out:
# Downloading:
#   results_sglang_baseline.csv
#   results_sglang_no_radix.csv
#   results_sglang_torch_compile.csv
#   results_sglang_combined_20260416_153257.csv
#   plot_sglang_goodput.png
#   plot_sglang_itl.png
#   plot_sglang_latency_vs_throughput.png
#   plot_sglang_scaling.png
#   plot_sglang_speedup_heatmap.png
#   plot_sglang_throughput.png
#   plot_sglang_ttft.png
